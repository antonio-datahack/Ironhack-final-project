# %% [markdown]
# <img src="../images/fake-news-quotes-01-830x467.jpeg" width="800" height="70" />

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.util import bigrams

import re
import datetime
# Out:
# [nltk_data] Downloading package stopwords to /Users/kilo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 1. Get data
# [data source](https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset)

# %%
df_0 = pd.read_csv("../data/archive/Fake.csv")
df_1 = pd.read_csv("../data/archive/True.csv")

# %% [markdown]
# ### 1. EDA

# %% [markdown]
# <img src="../images/Screenshot 2021-05-17 at 16.24.54.png
# " width="300" height="50" />

# %%
df_0.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_1.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
# adding category 0 to fake news and category 1 to true news
df_0["category"] = 0
df_1["category"] = 1

# %%
# concatenating dataframes
df = pd.concat([df_0, df_1],axis=0)
df = df.reset_index()
df = df.drop(['index'], axis=1)
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 44895  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  category
# 0      December 31, 2017         0
# 1      December 31, 2017         0
# 2      December 30, 2017         0
# 3      December 29, 2017         0
# 4      December 25, 2017         0
# ...                  ...       ...
# 44893   August 22, 2017          1
# 44894   August 22, 2017          1
# 44895   August 22, 2017          1
# 44896   August 22, 2017          1
# 44897   August 22, 2017          1
#
# [44898 rows x 5 columns]

# %%
# saving dataframe as CSV
df.to_csv(f'../data/df_fakenews_merge.csv', index=False)

# %%
# quick overview of the new dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     44898 non-null  object
#  1   text      44898 non-null  object
#  2   subject   44898 non-null  object
#  3   date      44898 non-null  object
#  4   category  44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
# Return the number of missing values in each column
df.isnull( ).sum( )
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# Number of unique elements in "subjetc" column
df["subject"].unique()
# Out:
# array(['News', 'politics', 'Government News', 'left-news', 'US_News',
#        'Middle-east', 'politicsNews', 'worldnews'], dtype=object)

# %%
# Statistical summary for numerical columns present in the dataset. 
# Not to much sense on this dataframe
df.describe()
# Out:
#            category
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
# getting number of dimensions as well as the size in each dimension
df.shape
# Out:
# (44898, 5)

# %%
# Ploting a first overview of the data
plt.figure(figsize=(13,5))
sns.countplot(x='subject', data=df, hue='category', color='#042f66')

plt.title('Article subjects by category', fontsize=24)
plt.ylabel('Total', fontsize=14)
plt.xlabel("")
plt.xticks(fontsize=14)
sns.set_style("dark")
plt.legend(['Real', 'Fake'])
plt.show()

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# <img src="../images/data_cleaning.jpeg" width="300" height="50" />

# %%
# Detect missing values for an array-like object.
df.isnull().sum()
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# removing a row that has a NaN or missing values in it.
df.dropna(inplace=True)

# %%
# analyzing duplicated values
df.duplicated().sum()
# Out:
# 209

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# counting duplicated rows in "title" column
df["title"].duplicated().sum()
# Out:
# 5960

# %%
df["text"].duplicated().sum()
# Out:
# 6043

# %% [markdown]
# ---------------

# %% [markdown]
# ##### I want to see how many duplicated "titles" and "texts" belong to fake_news

# %%
df_0["title"].duplicated().sum()
# Out:
# 5578

# %%
df_0["text"].duplicated().sum()
# Out:
# 6026

# %% [markdown]
# Most of the duplicated rows belong to fake news..... maybe this goes back to the need to repeat a message to reaffirm it or probably as well to the weak imagination of the inventors of lies.

# %% [markdown]
# -------

# %%
# drop duplicated rows on "text" column
df = df.drop_duplicates(subset=['text'])

# %%
# drop duplicated rows on "title" column
df = df.drop_duplicates(subset=['title'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38270 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     38270 non-null  object
#  1   text      38270 non-null  object
#  2   subject   38270 non-null  object
#  3   date      38270 non-null  object
#  4   category  38270 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.8+ MB

# %%
# preparing a sample to work on it better than working whit the whole dataframe
df_sample = df.sample(100)
df_sample
# Out:
#                                                    title  \
# 28658  U.S. Senators draft bill to boost employee pri...
# 4794    What Trump Wants To Do To Your Children Would...
# 16223  GUN GRABBING JUDGES Restrict Right To Own Comm...
# 10890  “SHE’S NO PUSHOVER”: How Sarah Huckabee Sander...
# 8510    Terrorist Jon Ritzheimer Uses Sobbing Daughte...
# ...                                                  ...
# 33368  U.S. to send more troops to Iraq to tackle Isl...
# 6601    Talk Show Host Whines That No One Called Geor...
# 43690  Exclusive: Scandal-hit Vietnam official had be...
# 11757  VIOLENT RIOT Shuts Down Free Speech Of Breitba...
# 28999  Ethics review sought after Trump adviser touts...
#
#                                                     text          subject  \
# 28658  WASHINGTON (Reuters) - A bipartisan pair of la...     politicsNews
# 4794   Donald Trump recently gave a speech to the Ame...             News
# 16223  In a 10-4 ruling, Maryland s Fourth Circuit ru...  Government News
# 10890  Deputy Press Secretary Sarah Huckabee Sanders ...         politics
# 8510   Jon Ritzheimer, infamous hater of Muslims and ...             News
# ...                                                  ...              ...
# 33368  BAGHDAD (Reuters) - The United States will sen...     politicsNews
# 6601   People have called former President George W. ...             News
# 43690  (Reuters) - A former Vietnamese official who G...        worldnews
# 11757  PRICELESS! MILO DESTROYS Heckling Muslim Woman...         politics
# 28999  WASHINGTON (Reuters) - (This February 9 story ...     politicsNews
#
#                       date  category
# 28658       March 2, 2017          1
# 4794     September 2, 2016         0
# 16223         Feb 23, 2017         0
# 10890         May 13, 2017         0
# 8510      January 26, 2016         0
# ...                    ...       ...
# 33368      April 18, 2016          1
# 6601           May 1, 2016         0
# 43690  September 13, 2017          1
# 11757          Feb 1, 2017         0
# 28999    February 9, 2017          1
#
# [100 rows x 5 columns]

# %%
# setting up the function to work on the sample and later work with the whole dataframe.
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

def stopwords(news):
    new_news = []
    news = news.lower()
    # news = re.sub(r'[^\w\s]+'," ",news) # removing characters
    news = re.sub(r'[^\w\s]','',news)
    news = re.sub('https?://\S+|www\.\S+', '', news) # removing link of web page from string
    news = re.sub("\d+", " ", news) # removing digits
    news = re.sub(r'(?:^| )\w(?:$| )', ' ', news) # removing any single letter on a string in python
    news = re.sub("reuters","", news) # removing the word routers
    for word in news.split():
        if word not in en_stops:
            new_news.append(word)
    news = " ".join(str(i) for i in new_news)
    return news

# %%
df_sample['text'] = df_sample['text'].apply(stopwords)
df_sample['title'] = df_sample['title'].apply(stopwords)
df_sample
# Out:
#                                                    title  \
# 28658  us senators draft bill boost employee private ...
# 4794                trump wants children would break law
# 16223  gun grabbing judges restrict right common fire...
# 10890  shes pushover sarah huckabee sanders made whit...
# 8510   terrorist jon ritzheimer uses sobbing daughter...
# ...                                                  ...
# 33368           us send troops iraq tackle islamic state
# 6601   talk show host whines one called george bush n...
# 43690  exclusive scandalhit vietnam official cleared ...
# 11757  violent riot shuts free speech breitbarts milo...
# 28999  ethics review sought trump adviser touts ivank...
#
#                                                     text          subject  \
# 28658  washington bipartisan pair lawmakers us senate...     politicsNews
# 4794   donald trump recently gave speech american leg...             News
# 16223  ruling maryland fourth circuit ruled could ban...  Government News
# 10890  deputy press secretary sarah huckabee sanders ...         politics
# 8510   jon ritzheimer infamous hater muslims one terr...             News
# ...                                                  ...              ...
# 33368  baghdad united states send troops iraq put clo...     politicsNews
# 6601   people called former president george bush lot...             News
# 43690  former vietnamese official germany says kidnap...        worldnews
# 11757  priceless milo destroys heckling muslim woman ...         politics
# 28999  washington february story refiled correct para...     politicsNews
#
#                       date  category
# 28658       March 2, 2017          1
# 4794     September 2, 2016         0
# 16223         Feb 23, 2017         0
# 10890         May 13, 2017         0
# 8510      January 26, 2016         0
# ...                    ...       ...
# 33368      April 18, 2016          1
# 6601           May 1, 2016         0
# 43690  September 13, 2017          1
# 11757          Feb 1, 2017         0
# 28999    February 9, 2017          1
#
# [100 rows x 5 columns]

# %%
# there some rows that have another information but not date-info I will delete them
df_sample = df_sample[df_sample['date'].str.len() < 22]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-69e75a2bbcb0> in <module>
#       1 # there some rows that have another information but not date-info I will delete them
# ----> 2 df_sample = df_sample[df_sample['date'].str.len() < 22]
#
# ~/opt/anaconda3/envs/excondables/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/envs/excondables/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ~/opt/anaconda3/envs/excondables/lib/python3.9/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     152         from pandas.core.arrays.string_ import StringDtype
#     153
# --> 154         self._inferred_dtype = self._validate(data)
#     155         self._is_categorical = is_categorical_dtype(data.dtype)
#     156         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/opt/anaconda3/envs/excondables/lib/python3.9/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     215
#     216         if inferred_dtype not in allowed_types:
# --> 217             raise AttributeError("Can only use .str accessor with string values!")
#     218         return inferred_dtype
#     219
#
# AttributeError: Can only use .str accessor with string values!

# %%
s = "string. With. Punctuation?"
s = re.sub(r'[^\w\s]','',s)

# %%
def date_time(dtime):
    print("object type: ",dtime.dtype)
    dtime =pd.to_datetime(dtime) # convert it to datetime
    print("object type: ",dtime.dtype) # check datatype again
    print("min time: ",dtime.min()) # check when data begin
    print("max time: ",dtime.max()) # check when data end
    dtime = dtime.apply(lambda x: x.toordinal()) # we will change the effective to date column to ordinal
    return dtime
df_sample['date'] = date_time(df_sample['date'])
# Out:
# object type:  int64
# object type:  datetime64[ns]
# min time:  1970-01-01 00:00:00.000735716
# max time:  1970-01-01 00:00:00.000736684

# %%
df_sample
# Out:
#                                                    title  \
# 41972  cambodia detained opposition leader denies tre...
# 10186  boom fox news host eric bolling hits back mill...
# 43521  irma creates bittersweet travel bonus luckier ...
# 25221  senate republican leader says daca part border...
# 9742   easy understand reasons ancestors illegals com...
# ...                                                  ...
# 13501  ha angry feminist senator attacks trump pence ...
# 7064   study shows profound negative impact religion ...
# 3532                carrier workers blast trump lied ass
# 14153             uh oh bill clinton unloads obama video
# 34086  connecticut cancels pay raises managers budget...
#
#                                                     text       subject  \
# 41972  phnom penh cambodia detained opposition leader...     worldnews
# 10186  bolling tweeted couple messages thanking suppo...      politics
# 43521  friday cruise ship carrying around passengers ...     worldnews
# 25221  washington u senate republican leader mitch mc...  politicsNews
# 9742   many times liberals used argument everyone rel...      politics
# ...                                                  ...           ...
# 13501  certainly hope hillary picks liz warren vp mis...      politics
# 7064   matter much republicans fox news say otherwise...          News
# 3532   donald trump bragging nonstop carrier deal sup...          News
# 14153  unlike president lot things coming apart aroun...      politics
# 34086  new york connecticut cancel pay raises manager...  politicsNews
#
#          date  category  length_text
# 41972  719163         1          202
# 10186  719163         0          227
# 43521  719163         1          396
# 25221  719163         1           55
# 9742   719163         0          147
# ...       ...       ...          ...
# 13501  719163         0           92
# 7064   719163         0          247
# 3532   719163         0          180
# 14153  719163         0          123
# 34086  719163         1          167
#
# [100 rows x 6 columns]

# %%
def split_words(news):
    news = news.split()
    return news

# %%
df_sample['text'] = df_sample['text'].apply(split_words)
df_sample['title'] = df_sample['title'].apply(split_words)
df_sample
# Out:
#                                                    title  \
# 41972  [cambodia, detained, opposition, leader, denie...
# 10186  [boom, fox, news, host, eric, bolling, hits, b...
# 43521  [irma, creates, bittersweet, travel, bonus, lu...
# 25221  [senate, republican, leader, says, daca, part,...
# 9742   [easy, understand, reasons, ancestors, illegal...
# ...                                                  ...
# 13501  [ha, angry, feminist, senator, attacks, trump,...
# 7064   [study, shows, profound, negative, impact, rel...
# 3532         [carrier, workers, blast, trump, lied, ass]
# 14153     [uh, oh, bill, clinton, unloads, obama, video]
# 34086  [connecticut, cancels, pay, raises, managers, ...
#
#                                                     text       subject  \
# 41972  [phnom, penh, cambodia, detained, opposition, ...     worldnews
# 10186  [bolling, tweeted, couple, messages, thanking,...      politics
# 43521  [friday, cruise, ship, carrying, around, passe...     worldnews
# 25221  [washington, u, senate, republican, leader, mi...  politicsNews
# 9742   [many, times, liberals, used, argument, everyo...      politics
# ...                                                  ...           ...
# 13501  [certainly, hope, hillary, picks, liz, warren,...      politics
# 7064   [matter, much, republicans, fox, news, say, ot...          News
# 3532   [donald, trump, bragging, nonstop, carrier, de...          News
# 14153  [unlike, president, lot, things, coming, apart...      politics
# 34086  [new, york, connecticut, cancel, pay, raises, ...  politicsNews
#
#          date  category  length_text
# 41972  719163         1          202
# 10186  719163         0          227
# 43521  719163         1          396
# 25221  719163         1           55
# 9742   719163         0          147
# ...       ...       ...          ...
# 13501  719163         0           92
# 7064   719163         0          247
# 3532   719163         0          180
# 14153  719163         0          123
# 34086  719163         1          167
#
# [100 rows x 6 columns]

# %%
# to detect the most repeated keywords in df_sample'text'.
words = [wrd for x in df_sample['text'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_text = Counter(words)
keywords_text = pd.DataFrame.from_dict(keywords_text, orient='index').reset_index()
keywords_text = keywords_text.sort_values(by=[0], ascending=False)
keywords_text.columns = ['word','count']
keywords_text.head(60)
# Out:
#              word  count
# 548         trump    371
# 73           said    319
# 480     president    149
# 104             u    132
# 501         would    131
# 127        people    105
# 660          also     94
# 644        donald     83
# 746           one     82
# 616         state     78
# 508         house     77
# 8      government     74
# 52           year     74
# 694       percent     72
# 1444      clinton     72
# 375         could     70
# 34         states     67
# 47          media     66
# 382           new     65
# 17          first     64
# 33         united     64
# 817           two     62
# 971      campaign     61
# 600      american     59
# 520    republican     56
# 431          time     55
# 3677          nbk     55
# 727         obama     54
# 28          party     54
# 409          well     53
# 21           last     51
# 509      military     49
# 975          like     49
# 745         white     49
# 3690       mickey     47
# 494          many     47
# 955          told     46
# 199       million     45
# 3691      mallory     44
# 54         former     44
# 82        country     44
# 384     according     43
# 222         going     42
# 518    washington     42
# 1447  republicans     41
# 181          news     41
# 895           see     41
# 573       america     40
# 956           get     40
# 403         right     39
# 519        senate     39
# 532      security     38
# 479          much     38
# 92            say     37
# 452          made     37
# 100        public     36
# 60          three     36
# 791       foreign     36
# 636         years     36
# 439         world     36

# %%
# to detect the most repeated keywords in df_sample'title'.
words = [wrd for x in df_sample['title'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_title = Counter(words)
keywords_title = pd.DataFrame.from_dict(keywords_title, orient='index').reset_index()
keywords_title = keywords_title.sort_values(by=[0], ascending=False)
keywords_title.columns = ['word','count']
keywords_title.head(60)
# Out:
#             word  count
# 49         trump     37
# 63         video     16
# 33          says     11
# 170            u     10
# 216        obama      9
# 120      clinton      7
# 9           news      6
# 282   government      5
# 117          new      5
# 169      foreign      4
# 102     breaking      4
# 32    republican      4
# 119        shows      4
# 293        syria      4
# 8            fox      4
# 133        house      4
# 52         calls      4
# 55           gap      3
# 299            n      3
# 163       attack      3
# 36        border      3
# 147     governor      3
# 31        senate      3
# 51         india      3
# 172        court      3
# 322        media      3
# 225       little      3
# 382       russia      3
# 180  republicans      3
# 3         leader      3
# 193       donald      3
# 81        policy      3
# 203       puerto      3
# 15       million      3
# 383        chief      3
# 451        watch      2
# 134          tax      2
# 93       central      2
# 94       african      2
# 95      republic      2
# 473          yet      2
# 123         lead      2
# 110        never      2
# 454        woman      2
# 457          law      2
# 118         poll      2
# 455         life      2
# 116        audio      2
# 115      hannity      2
# 315       ricans      2
# 314      florida      2
# 619       raises      2
# 456       sharia      2
# 99       workers      2
# 195         like      2
# 292       tweets      2
# 177         case      2
# 219        japan      2
# 534       turkey      2
# 521       debate      2

# %%
df_sample.head(5)
# Out:
#                                                    title  \
# 41972  [cambodia, detained, opposition, leader, denie...
# 10186  [boom, fox, news, host, eric, bolling, hits, b...
# 43521  [irma, creates, bittersweet, travel, bonus, lu...
# 25221  [senate, republican, leader, says, daca, part,...
# 9742   [4, easy, understand, reasons, ancestors, ille...
#
#                                                     text       subject  \
# 41972  [phnom, penh, cambodia, detained, opposition, ...     worldnews
# 10186  [bolling, tweeted, couple, messages, thanking,...      politics
# 43521  [friday, cruise, ship, carrying, around, passe...     worldnews
# 25221  [washington, u, senate, republican, leader, mi...  politicsNews
# 9742   [many, times, liberals, used, argument, everyo...      politics
#
#          date  category
# 41972  736604         1
# 10186  736550         0
# 43521  736586         1
# 25221  736586         1
# 9742   736607         0

# %%
df_sample.iloc[4,1]
# Out:
# ['many',
#  'times',
#  'liberals',
#  'used',
#  'argument',
#  'everyone',
#  'relatives',
#  'came',
#  'illegally',
#  'answer',
#  'million',
#  'times',
#  'liberals',
#  'seem',
#  'differentiate',
#  'people',
#  'came',
#  'nation',
#  'either',
#  'escape',
#  'persecution',
#  'find',
#  'better',
#  'life',
#  'came',
#  'ellis',
#  'island',
#  'immediately',
#  'applied',
#  'citizenship',
#  'america',
#  'float',
#  'across',
#  'rio',
#  'grande',
#  'inner',
#  'tube',
#  'paying',
#  'coyote',
#  'fee',
#  'help',
#  'illegally',
#  'cross',
#  'borders',
#  'meme',
#  'brilliantly',
#  'explains',
#  'difference',
#  'short',
#  'bullet',
#  'points',
#  'little',
#  'visual',
#  'anyone',
#  'tells',
#  'true',
#  'estimated',
#  'million',
#  'illegal',
#  'aliens',
#  'currently',
#  'living',
#  'united',
#  'states',
#  'series',
#  'visuals',
#  'federation',
#  'american',
#  'immigration',
#  'reform',
#  'fair',
#  'help',
#  'americans',
#  'understand',
#  'cost',
#  'illegal',
#  'immigration',
#  'taxpaying',
#  'americans',
#  'data',
#  'september',
#  'paints',
#  'pretty',
#  'bleak',
#  'economic',
#  'picture',
#  'america',
#  'continue',
#  'ignore',
#  'serious',
#  'problem',
#  'illegal',
#  'immigration',
#  'fair',
#  'federal',
#  'state',
#  'local',
#  'levels',
#  'taxpayers',
#  'shell',
#  'approximately',
#  'billion',
#  'cover',
#  'costs',
#  'incurred',
#  'presence',
#  'million',
#  'illegal',
#  'aliens',
#  'million',
#  'citizen',
#  'children',
#  'illegal',
#  'aliens',
#  'amounts',
#  'tax',
#  'burden',
#  'approximately',
#  'per',
#  'illegal',
#  'alien',
#  'family',
#  'member',
#  'total',
#  'total',
#  'cost',
#  'illegal',
#  'immigration',
#  'u',
#  'taxpayers',
#  'staggering',
#  'crippling',
#  'fair',
#  'estimated',
#  'total',
#  'cost',
#  'approximately',
#  'billion',
#  'four',
#  'years',
#  'cost',
#  'risen',
#  'nearly',
#  'billion',
#  'disturbing',
#  'unsustainable',
#  'trend']

# %% [markdown]
# Before join the list I want to find the combinations words

# %% [markdown]
# voy a poner todos los textos juntos en una variable

# %%
all_texts1 = []
for i in df_sample["text"]:
    all_texts1 += i
all_texts1
# Out:
# ['phnom',
#  'penh',
#  'cambodia',
#  'detained',
#  'opposition',
#  'leader',
#  'accused',
#  'treason',
#  'government',
#  'strongman',
#  'prime',
#  'minister',
#  'hun',
#  'sen',
#  'denied',
#  'charges',
#  'monday',
#  'first',
#  'comments',
#  'since',
#  'arrest',
#  'last',
#  'month',
#  'kem',
#  'sokha',
#  'head',
#  'opposition',
#  'cambodia',
#  'national',
#  'rescue',
#  'party',
#  'cnrp',
#  'accused',
#  'trying',
#  'overthrow',
#  'government',
#  'help',
#  'united',
#  'states',
#  'espionage',
#  'charges',
#  'denies',
#  'says',
#  'politically',
#  'motivated',
#  'arrest',
#  'last',
#  'month',
#  'part',
#  'ongoing',
#  'efforts',
#  'government',
#  'silence',
#  'political',
#  'opponents',
#  'independent',
#  'media',
#  'ahead',
#  'general',
#  'election',
#  'next',
#  'year',
#  'earlier',
#  'monday',
#  'hun',
#  'sen',
#  'former',
#  'khmer',
#  'rouge',
#  'officer',
#  'defected',
#  'ruled',
#  'cambodia',
#  'three',
#  'decades',
#  'attacked',
#  'opposition',
#  'figures',
#  'rebels',
#  'city',
#  'bent',
#  'staging',
#  'revolution',
#  'three',
#  'page',
#  'letter',
#  'posted',
#  'facebook',
#  'page',
#  'monday',
#  'kem',
#  'sokha',
#  'said',
#  'seeking',
#  'positive',
#  'change',
#  'cambodia',
#  'ballot',
#  'box',
#  'revolution',
#  'charged',
#  'leader',
#  'cnrp',
#  'representative',
#  'half',
#  'country',
#  'population',
#  'always',
#  'choose',
#  'changes',
#  'elections',
#  'without',
#  'violence',
#  'said',
#  'letter',
#  'rights',
#  'groups',
#  'say',
#  'hun',
#  'sen',
#  'determined',
#  'extend',
#  'rule',
#  'dismantle',
#  'burgeoning',
#  'popularity',
#  'cnrp',
#  'gained',
#  'public',
#  'anger',
#  'inequality',
#  'cronyism',
#  'country',
#  'hun',
#  'sen',
#  'rule',
#  'u',
#  'embassy',
#  'rejected',
#  'suggestion',
#  'interference',
#  'politics',
#  'kem',
#  'sokha',
#  'sept',
#  'arrest',
#  'sparked',
#  'condemnation',
#  'western',
#  'countries',
#  'cnrp',
#  'said',
#  'half',
#  'members',
#  'parliament',
#  'fled',
#  'cambodia',
#  'fearing',
#  'crackdown',
#  'letter',
#  'kem',
#  'sokha',
#  'called',
#  'arrest',
#  'unconstitutional',
#  'urged',
#  'supporters',
#  'intimidated',
#  'please',
#  'cambodian',
#  'people',
#  'remember',
#  'even',
#  'though',
#  'body',
#  'prison',
#  'nobody',
#  'detain',
#  'conscience',
#  'said',
#  'called',
#  'international',
#  'community',
#  'help',
#  'democracy',
#  'cambodia',
#  'already',
#  'last',
#  'breathe',
#  'said',
#  'spokesman',
#  'hun',
#  'sen',
#  'cambodian',
#  'people',
#  'party',
#  'cpp',
#  'said',
#  'kem',
#  'sokha',
#  'confessed',
#  'charges',
#  'bolling',
#  'tweeted',
#  'couple',
#  'messages',
#  'thanking',
#  'supporters',
#  'standing',
#  'bolling',
#  'huffington',
#  'post',
#  'reporter',
#  'yashar',
#  'ali',
#  'goes',
#  'jugular',
#  'overwhelmed',
#  'support',
#  'received',
#  'thank',
#  'youi',
#  'look',
#  'forward',
#  'clearing',
#  'name',
#  'asap',
#  'eric',
#  'bolling',
#  'ericbolling',
#  'august',
#  'tweet',
#  'bolling',
#  'claims',
#  'accusations',
#  'false',
#  'smear',
#  'attacks',
#  'continue',
#  'fight',
#  'false',
#  'smear',
#  'attacks',
#  'thank',
#  'continued',
#  'support',
#  'eric',
#  'bolling',
#  'ericbolling',
#  'august',
#  'hill',
#  'fox',
#  'news',
#  'host',
#  'eric',
#  'bolling',
#  'reportedly',
#  'suing',
#  'huffington',
#  'post',
#  'reporter',
#  'broke',
#  'story',
#  'last',
#  'week',
#  'included',
#  'several',
#  'female',
#  'co',
#  'workers',
#  'claiming',
#  'bolling',
#  'sent',
#  'lewd',
#  'photos',
#  'received',
#  'summons',
#  'eric',
#  'bolling',
#  'suing',
#  'defamation',
#  'million',
#  'damages',
#  'yashar',
#  'ali',
#  'huffpost',
#  'contributing',
#  'writer',
#  'tweeted',
#  'twitter',
#  'followers',
#  'wednesday',
#  'stand',
#  'reporting',
#  'protect',
#  'sources',
#  'received',
#  'summons',
#  'eric',
#  'bolling',
#  'suing',
#  'defamation',
#  'million',
#  'damages',
#  'stand',
#  'reporting',
#  'protect',
#  'sources',
#  'yashar',
#  'ali',
#  'yashar',
#  'august',
#  'ali',
#  'clarifies',
#  'next',
#  'post',
#  'bolling',
#  'suing',
#  'huffington',
#  'post',
#  'important',
#  'note',
#  'bolling',
#  'summons',
#  'include',
#  'huffpost',
#  'coming',
#  'personally',
#  'big',
#  'boy',
#  'telling',
#  'https',
#  'co',
#  'nvludsiv87',
#  'yashar',
#  'ali',
#  'yashar',
#  'august',
#  'going',
#  'stop',
#  'reporting',
#  'eric',
#  'bolling',
#  'anyone',
#  'else',
#  'family',
#  'members',
#  'killed',
#  'jailed',
#  'iran',
#  'lawsuit',
#  'going',
#  'scare',
#  'https',
#  'co',
#  'nvludsiv87',
#  'yashar',
#  'ali',
#  'yashar',
#  'august',
#  'nature',
#  'action',
#  'damages',
#  'injunctive',
#  'relief',
#  'based',
#  'defamation',
#  'arising',
#  'defendant',
#  'efforts',
#  'injure',
#  'plaintiff',
#  'reputation',
#  'intentional',
#  'highly',
#  'reckless',
#  'publication',
#  'actionable',
#  'false',
#  'misleading',
#  'statements',
#  'plaintiff',
#  'conduct',
#  'character',
#  'result',
#  'defendant',
#  'actions',
#  'plaintiff',
#  'substantially',
#  'harmed',
#  'reads',
#  'summons',
#  'sent',
#  'ali',
#  'editor',
#  'chief',
#  'huffington',
#  'post',
#  'tweeted',
#  'outlet',
#  'standing',
#  'ali',
#  'case',
#  'yashar',
#  'ali',
#  'paid',
#  'freelancer',
#  'contract',
#  'huffpost',
#  'hesitation',
#  'standing',
#  'financially',
#  'case',
#  'lydia',
#  'polgreen',
#  'lpolgreen',
#  'august',
#  'huffpost',
#  'says',
#  'hesitation',
#  'financially',
#  'stand',
#  'yashar',
#  'ericbolling',
#  'case',
#  'hadas',
#  'gold',
#  'hadas_gold',
#  'august',
#  'friday',
#  'cruise',
#  'ship',
#  'carrying',
#  'around',
#  'passengers',
#  'dock',
#  'st',
#  'john',
#  'harbor',
#  'caribbean',
#  'island',
#  'antigua',
#  'passengers',
#  'expected',
#  'land',
#  'booked',
#  'however',
#  'carnival',
#  'plc',
#  'ship',
#  'meant',
#  'dock',
#  'saint',
#  'martin',
#  'miles',
#  'km',
#  'northwest',
#  'however',
#  'hurricane',
#  'irma',
#  'devastated',
#  'island',
#  'wrecking',
#  'port',
#  'infrastructure',
#  'leaving',
#  'bounds',
#  'tourists',
#  'antiguan',
#  'officials',
#  'expect',
#  'carnival',
#  'fascination',
#  'visit',
#  'every',
#  'friday',
#  'gotten',
#  'calls',
#  'major',
#  'cruise',
#  'lines',
#  'royal',
#  'caribbean',
#  'cruises',
#  'ltd',
#  'norwegian',
#  'cruise',
#  'lines',
#  'looking',
#  'make',
#  'stops',
#  'end',
#  'year',
#  'asot',
#  'michael',
#  'antigua',
#  'barbuda',
#  'minister',
#  'tourism',
#  'unexpected',
#  'arrival',
#  'thousands',
#  'tourists',
#  'bittersweet',
#  'bonus',
#  'going',
#  'benefiting',
#  'want',
#  'benefit',
#  'others',
#  'misfortune',
#  'disaster',
#  'michael',
#  'said',
#  'port',
#  'damaged',
#  'saint',
#  'martin',
#  'damaged',
#  'tortola',
#  'british',
#  'virgin',
#  'islands',
#  'getting',
#  'cancellations',
#  'cruise',
#  'lines',
#  'making',
#  'ports',
#  'call',
#  'antigua',
#  'hurricane',
#  'irma',
#  'left',
#  'behind',
#  'stark',
#  'divide',
#  'caribbean',
#  'ahead',
#  'winter',
#  'tourism',
#  'season',
#  'region',
#  'economic',
#  'lifeblood',
#  'travel',
#  'region',
#  'picks',
#  'cruise',
#  'lines',
#  'hotels',
#  'airlines',
#  'companies',
#  'directing',
#  'customers',
#  'places',
#  'able',
#  'host',
#  'away',
#  'worst',
#  'hit',
#  'areas',
#  'popular',
#  'winter',
#  'vacation',
#  'spots',
#  'saint',
#  'martin',
#  'british',
#  'virgin',
#  'islands',
#  'saint',
#  'barthelemy',
#  'devastated',
#  'storm',
#  'could',
#  'sidelined',
#  'weeks',
#  'months',
#  'million',
#  'tourists',
#  'visited',
#  'caribbean',
#  'spent',
#  'billion',
#  'new',
#  'records',
#  'according',
#  'caribbean',
#  'tourism',
#  'organization',
#  'saint',
#  'martin',
#  'saint',
#  'bart',
#  'holiday',
#  'season',
#  'looks',
#  'compromised',
#  'said',
#  'jean',
#  'pierre',
#  'mas',
#  'chairman',
#  'french',
#  'travel',
#  'agency',
#  'federation',
#  'snav',
#  'sentiment',
#  'winter',
#  'season',
#  'lost',
#  'decisions',
#  'book',
#  'winter',
#  'season',
#  'taken',
#  'right',
#  'busy',
#  'tourist',
#  'destinations',
#  'western',
#  'caribbean',
#  'barbados',
#  'trinidad',
#  'well',
#  'away',
#  'path',
#  'storm',
#  'cozumel',
#  'mexico',
#  'gulf',
#  'coast',
#  'got',
#  'four',
#  'additional',
#  'visits',
#  'week',
#  'ships',
#  'rerouted',
#  'avoid',
#  'storm',
#  'impact',
#  'although',
#  'cozumel',
#  'tourism',
#  'officials',
#  'said',
#  'three',
#  'cruises',
#  'canceled',
#  'florida',
#  'anticipating',
#  'another',
#  'record',
#  'year',
#  'billion',
#  'year',
#  'tourism',
#  'industry',
#  'expected',
#  'rebound',
#  'time',
#  'peak',
#  'winter',
#  'travel',
#  'months',
#  'moody',
#  'analytics',
#  'said',
#  'earlier',
#  'week',
#  'walt',
#  'disney',
#  'co',
#  'reopened',
#  'orlando',
#  'disney',
#  'world',
#  'theme',
#  'park',
#  'sept',
#  'florida',
#  'keys',
#  'however',
#  'wrestled',
#  'severe',
#  'storm',
#  'damage',
#  'nl2n1lr0n1',
#  'nf9n1l0029',
#  'nl2n1ls1hw',
#  'travel',
#  'companies',
#  'said',
#  'still',
#  'assessing',
#  'situation',
#  'made',
#  'firm',
#  'decisions',
#  'rerouting',
#  'ships',
#  'tour',
#  'operator',
#  'virgin',
#  'holidays',
#  'said',
#  'beginning',
#  'return',
#  'regular',
#  'operations',
#  'antigua',
#  'despite',
#  'damage',
#  'properties',
#  'island',
#  'antigua',
#  'badly',
#  'damaged',
#  'feared',
#  'reopened',
#  'tourism',
#  'although',
#  'three',
#  'resorts',
#  'currently',
#  'sale',
#  'damage',
#  'spokesman',
#  'virgin',
#  'atlantic',
#  'said',
#  'barbados',
#  'trinidad',
#  'tobago',
#  'st',
#  'lucia',
#  'three',
#  'big',
#  'tourist',
#  'examples',
#  'impacted',
#  'however',
#  'small',
#  'island',
#  'saint',
#  'martin',
#  'france',
#  'shares',
#  'netherlands',
#  'could',
#  'miss',
#  'much',
#  'tourism',
#  'season',
#  'french',
#  'president',
#  'emmanuel',
#  'macron',
#  'wednesday',
#  'vowed',
#  'swiftly',
#  'rebuild',
#  'islands',
#  'french',
#  'caribbean',
#  'including',
#  'saint',
#  'martin',
#  'french',
#  'public',
#  'reinsurance',
#  'body',
#  'estimated',
#  'cost',
#  'least',
#  'billion',
#  'euros',
#  'billion',
#  'damage',
#  'saint',
#  'barthelemy',
#  'nl2n1lt1sf',
#  'nl5n1lq09g',
#  'hurricane',
#  'irma',
#  'badly',
#  'damaged',
#  'many',
#  'hotels',
#  'island',
#  'accorhotels',
#  'mercure',
#  'hotel',
#  'spokeswoman',
#  'accor',
#  'said',
#  'nobody',
#  'hurt',
#  'hotel',
#  'would',
#  'closed',
#  'jan',
#  'least',
#  'hotel',
#  'rooms',
#  'remain',
#  'operational',
#  'used',
#  'house',
#  'military',
#  'forces',
#  'staff',
#  'supporting',
#  'relief',
#  'effort',
#  'accorhotels',
#  'offering',
#  'cancellation',
#  'reimbursement',
#  'booked',
#  'stays',
#  'hotel',
#  'washington',
#  'u',
#  'senate',
#  'republican',
#  'leader',
#  'mitch',
#  'mcconnell',
#  'said',
#  'thursday',
#  'daca',
#  'program',
#  'people',
#  'arrived',
#  'country',
#  'illegally',
#  'children',
#  'part',
#  'larger',
#  'discussion',
#  'border',
#  'security',
#  'congress',
#  'would',
#  'welcome',
#  'proposal',
#  'address',
#  'issues',
#  'congress',
#  'debates',
#  'best',
#  'ways',
#  'address',
#  'illegal',
#  'immigration',
#  'strong',
#  'border',
#  'security',
#  'interior',
#  'enforcement',
#  'daca',
#  'part',
#  'discussions',
#  'look',
#  'forward',
#  'receiving',
#  'trump',
#  'administration',
#  'legislative',
#  'proposal',
#  'continue',
#  'work',
#  'issues',
#  'mcconnell',
#  'said',
#  'statement',
#  'many',
#  'times',
#  'liberals',
#  'used',
#  'argument',
#  'everyone',
#  'relatives',
#  'came',
#  'illegally',
#  'answer',
#  'million',
#  'times',
#  'liberals',
#  'seem',
#  'differentiate',
#  'people',
#  'came',
#  'nation',
#  'either',
#  'escape',
#  'persecution',
#  'find',
#  'better',
#  'life',
#  'came',
#  'ellis',
#  'island',
#  'immediately',
#  'applied',
#  'citizenship',
#  'america',
#  'float',
#  'across',
#  'rio',
#  'grande',
#  'inner',
#  'tube',
#  'paying',
#  'coyote',
#  'fee',
#  'help',
#  'illegally',
#  'cross',
#  'borders',
#  'meme',
#  'brilliantly',
#  'explains',
#  'difference',
#  'short',
#  'bullet',
#  'points',
#  'little',
#  'visual',
#  'anyone',
#  'tells',
#  'true',
#  'estimated',
#  'million',
#  'illegal',
#  'aliens',
#  'currently',
#  'living',
#  'united',
#  'states',
#  'series',
#  'visuals',
#  'federation',
#  'american',
#  'immigration',
#  'reform',
#  'fair',
#  'help',
#  'americans',
#  'understand',
#  'cost',
#  'illegal',
#  'immigration',
#  'taxpaying',
#  'americans',
#  'data',
#  'september',
#  'paints',
#  'pretty',
#  'bleak',
#  'economic',
#  'picture',
#  'america',
#  'continue',
#  'ignore',
#  'serious',
#  'problem',
#  'illegal',
#  'immigration',
#  'fair',
#  'federal',
#  'state',
#  'local',
#  'levels',
#  'taxpayers',
#  'shell',
#  'approximately',
#  'billion',
#  'cover',
#  'costs',
#  'incurred',
#  'presence',
#  'million',
#  'illegal',
#  'aliens',
#  'million',
#  'citizen',
#  'children',
#  'illegal',
#  'aliens',
#  'amounts',
#  'tax',
#  'burden',
#  'approximately',
#  'per',
#  'illegal',
#  ...]

# %%
from nltk.probability import FreqDist
all_texts2 = [Counter(list(bigrams(all_texts1)))]
all_texts2
# Out:
# [Counter({('phnom', 'penh'): 1,
#           ('penh', 'cambodia'): 1,
#           ('cambodia', 'detained'): 1,
#           ('detained', 'opposition'): 1,
#           ('opposition', 'leader'): 2,
#           ('leader', 'accused'): 1,
#           ('accused', 'treason'): 1,
#           ('treason', 'government'): 1,
#           ('government', 'strongman'): 1,
#           ('strongman', 'prime'): 1,
#           ('prime', 'minister'): 19,
#           ('minister', 'hun'): 1,
#           ('hun', 'sen'): 5,
#           ('sen', 'denied'): 1,
#           ('denied', 'charges'): 2,
#           ('charges', 'monday'): 1,
#           ('monday', 'first'): 1,
#           ('first', 'comments'): 1,
#           ('comments', 'since'): 1,
#           ('since', 'arrest'): 1,
#           ('arrest', 'last'): 2,
#           ('last', 'month'): 8,
#           ('month', 'kem'): 1,
#           ('kem', 'sokha'): 5,
#           ('sokha', 'head'): 1,
#           ('head', 'opposition'): 1,
#           ('opposition', 'cambodia'): 1,
#           ('cambodia', 'national'): 1,
#           ('national', 'rescue'): 1,
#           ('rescue', 'party'): 1,
#           ('party', 'cnrp'): 1,
#           ('cnrp', 'accused'): 1,
#           ('accused', 'trying'): 1,
#           ('trying', 'overthrow'): 1,
#           ('overthrow', 'government'): 1,
#           ('government', 'help'): 2,
#           ('help', 'united'): 1,
#           ('united', 'states'): 50,
#           ('states', 'espionage'): 1,
#           ('espionage', 'charges'): 1,
#           ('charges', 'denies'): 1,
#           ('denies', 'says'): 1,
#           ('says', 'politically'): 1,
#           ('politically', 'motivated'): 3,
#           ('motivated', 'arrest'): 1,
#           ('month', 'part'): 1,
#           ('part', 'ongoing'): 1,
#           ('ongoing', 'efforts'): 1,
#           ('efforts', 'government'): 1,
#           ('government', 'silence'): 1,
#           ('silence', 'political'): 1,
#           ('political', 'opponents'): 2,
#           ('opponents', 'independent'): 1,
#           ('independent', 'media'): 1,
#           ('media', 'ahead'): 1,
#           ('ahead', 'general'): 2,
#           ('general', 'election'): 4,
#           ('election', 'next'): 2,
#           ('next', 'year'): 7,
#           ('year', 'earlier'): 1,
#           ('earlier', 'monday'): 1,
#           ('monday', 'hun'): 1,
#           ('sen', 'former'): 1,
#           ('former', 'khmer'): 1,
#           ('khmer', 'rouge'): 2,
#           ('rouge', 'officer'): 1,
#           ('officer', 'defected'): 1,
#           ('defected', 'ruled'): 1,
#           ('ruled', 'cambodia'): 1,
#           ('cambodia', 'three'): 1,
#           ('three', 'decades'): 3,
#           ('decades', 'attacked'): 1,
#           ('attacked', 'opposition'): 1,
#           ('opposition', 'figures'): 1,
#           ('figures', 'rebels'): 1,
#           ('rebels', 'city'): 1,
#           ('city', 'bent'): 1,
#           ('bent', 'staging'): 1,
#           ('staging', 'revolution'): 1,
#           ('revolution', 'three'): 1,
#           ('three', 'page'): 1,
#           ('page', 'letter'): 1,
#           ('letter', 'posted'): 1,
#           ('posted', 'facebook'): 1,
#           ('facebook', 'page'): 6,
#           ('page', 'monday'): 1,
#           ('monday', 'kem'): 1,
#           ('sokha', 'said'): 1,
#           ('said', 'seeking'): 1,
#           ('seeking', 'positive'): 1,
#           ('positive', 'change'): 1,
#           ('change', 'cambodia'): 1,
#           ('cambodia', 'ballot'): 1,
#           ('ballot', 'box'): 1,
#           ('box', 'revolution'): 1,
#           ('revolution', 'charged'): 1,
#           ('charged', 'leader'): 1,
#           ('leader', 'cnrp'): 1,
#           ('cnrp', 'representative'): 1,
#           ('representative', 'half'): 1,
#           ('half', 'country'): 1,
#           ('country', 'population'): 1,
#           ('population', 'always'): 1,
#           ('always', 'choose'): 1,
#           ('choose', 'changes'): 1,
#           ('changes', 'elections'): 1,
#           ('elections', 'without'): 1,
#           ('without', 'violence'): 1,
#           ('violence', 'said'): 1,
#           ('said', 'letter'): 1,
#           ('letter', 'rights'): 1,
#           ('rights', 'groups'): 1,
#           ('groups', 'say'): 1,
#           ('say', 'hun'): 1,
#           ('sen', 'determined'): 1,
#           ('determined', 'extend'): 1,
#           ('extend', 'rule'): 1,
#           ('rule', 'dismantle'): 1,
#           ('dismantle', 'burgeoning'): 1,
#           ('burgeoning', 'popularity'): 1,
#           ('popularity', 'cnrp'): 1,
#           ('cnrp', 'gained'): 1,
#           ('gained', 'public'): 1,
#           ('public', 'anger'): 1,
#           ('anger', 'inequality'): 1,
#           ('inequality', 'cronyism'): 1,
#           ('cronyism', 'country'): 1,
#           ('country', 'hun'): 1,
#           ('sen', 'rule'): 1,
#           ('rule', 'u'): 1,
#           ('u', 'embassy'): 1,
#           ('embassy', 'rejected'): 1,
#           ('rejected', 'suggestion'): 1,
#           ('suggestion', 'interference'): 1,
#           ('interference', 'politics'): 1,
#           ('politics', 'kem'): 1,
#           ('sokha', 'sept'): 1,
#           ('sept', 'arrest'): 1,
#           ('arrest', 'sparked'): 1,
#           ('sparked', 'condemnation'): 1,
#           ('condemnation', 'western'): 1,
#           ('western', 'countries'): 1,
#           ('countries', 'cnrp'): 1,
#           ('cnrp', 'said'): 1,
#           ('said', 'half'): 1,
#           ('half', 'members'): 1,
#           ('members', 'parliament'): 1,
#           ('parliament', 'fled'): 1,
#           ('fled', 'cambodia'): 1,
#           ('cambodia', 'fearing'): 1,
#           ('fearing', 'crackdown'): 1,
#           ('crackdown', 'letter'): 1,
#           ('letter', 'kem'): 1,
#           ('sokha', 'called'): 1,
#           ('called', 'arrest'): 1,
#           ('arrest', 'unconstitutional'): 1,
#           ('unconstitutional', 'urged'): 1,
#           ('urged', 'supporters'): 1,
#           ('supporters', 'intimidated'): 1,
#           ('intimidated', 'please'): 1,
#           ('please', 'cambodian'): 1,
#           ('cambodian', 'people'): 2,
#           ('people', 'remember'): 1,
#           ('remember', 'even'): 1,
#           ('even', 'though'): 4,
#           ('though', 'body'): 1,
#           ('body', 'prison'): 1,
#           ('prison', 'nobody'): 1,
#           ('nobody', 'detain'): 1,
#           ('detain', 'conscience'): 1,
#           ('conscience', 'said'): 1,
#           ('said', 'called'): 2,
#           ('called', 'international'): 1,
#           ('international', 'community'): 4,
#           ('community', 'help'): 1,
#           ('help', 'democracy'): 1,
#           ('democracy', 'cambodia'): 1,
#           ('cambodia', 'already'): 1,
#           ('already', 'last'): 1,
#           ('last', 'breathe'): 1,
#           ('breathe', 'said'): 1,
#           ('said', 'spokesman'): 1,
#           ('spokesman', 'hun'): 1,
#           ('sen', 'cambodian'): 1,
#           ('people', 'party'): 2,
#           ('party', 'cpp'): 1,
#           ('cpp', 'said'): 1,
#           ('said', 'kem'): 1,
#           ('sokha', 'confessed'): 1,
#           ('confessed', 'charges'): 1,
#           ('charges', 'bolling'): 1,
#           ('bolling', 'tweeted'): 1,
#           ('tweeted', 'couple'): 1,
#           ('couple', 'messages'): 1,
#           ('messages', 'thanking'): 1,
#           ('thanking', 'supporters'): 1,
#           ('supporters', 'standing'): 1,
#           ('standing', 'bolling'): 1,
#           ('bolling', 'huffington'): 1,
#           ('huffington', 'post'): 4,
#           ('post', 'reporter'): 2,
#           ('reporter', 'yashar'): 1,
#           ('yashar', 'ali'): 6,
#           ('ali', 'goes'): 1,
#           ('goes', 'jugular'): 1,
#           ('jugular', 'overwhelmed'): 1,
#           ('overwhelmed', 'support'): 1,
#           ('support', 'received'): 1,
#           ('received', 'thank'): 1,
#           ('thank', 'youi'): 1,
#           ('youi', 'look'): 1,
#           ('look', 'forward'): 3,
#           ('forward', 'clearing'): 1,
#           ('clearing', 'name'): 1,
#           ('name', 'asap'): 1,
#           ('asap', 'eric'): 1,
#           ('eric', 'bolling'): 6,
#           ('bolling', 'ericbolling'): 2,
#           ('ericbolling', 'august'): 2,
#           ('august', 'tweet'): 1,
#           ('tweet', 'bolling'): 1,
#           ('bolling', 'claims'): 1,
#           ('claims', 'accusations'): 1,
#           ('accusations', 'false'): 1,
#           ('false', 'smear'): 2,
#           ('smear', 'attacks'): 2,
#           ('attacks', 'continue'): 1,
#           ('continue', 'fight'): 3,
#           ('fight', 'false'): 1,
#           ('attacks', 'thank'): 1,
#           ('thank', 'continued'): 1,
#           ('continued', 'support'): 1,
#           ('support', 'eric'): 1,
#           ('august', 'hill'): 1,
#           ('hill', 'fox'): 1,
#           ('fox', 'news'): 13,
#           ('news', 'host'): 2,
#           ('host', 'eric'): 1,
#           ('bolling', 'reportedly'): 1,
#           ('reportedly', 'suing'): 1,
#           ('suing', 'huffington'): 2,
#           ('reporter', 'broke'): 1,
#           ('broke', 'story'): 1,
#           ('story', 'last'): 1,
#           ('last', 'week'): 8,
#           ('week', 'included'): 1,
#           ('included', 'several'): 1,
#           ('several', 'female'): 1,
#           ('female', 'co'): 1,
#           ('co', 'workers'): 2,
#           ('workers', 'claiming'): 1,
#           ('claiming', 'bolling'): 1,
#           ('bolling', 'sent'): 1,
#           ('sent', 'lewd'): 1,
#           ('lewd', 'photos'): 1,
#           ('photos', 'received'): 1,
#           ('received', 'summons'): 2,
#           ('summons', 'eric'): 2,
#           ('bolling', 'suing'): 3,
#           ('suing', 'defamation'): 2,
#           ('defamation', 'million'): 2,
#           ('million', 'damages'): 2,
#           ('damages', 'yashar'): 1,
#           ('ali', 'huffpost'): 1,
#           ('huffpost', 'contributing'): 1,
#           ('contributing', 'writer'): 1,
#           ('writer', 'tweeted'): 1,
#           ('tweeted', 'twitter'): 1,
#           ('twitter', 'followers'): 1,
#           ('followers', 'wednesday'): 1,
#           ('wednesday', 'stand'): 1,
#           ('stand', 'reporting'): 2,
#           ('reporting', 'protect'): 2,
#           ('protect', 'sources'): 2,
#           ('sources', 'received'): 1,
#           ('damages', 'stand'): 1,
#           ('sources', 'yashar'): 1,
#           ('ali', 'yashar'): 3,
#           ('yashar', 'august'): 3,
#           ('august', 'ali'): 1,
#           ('ali', 'clarifies'): 1,
#           ('clarifies', 'next'): 1,
#           ('next', 'post'): 1,
#           ('post', 'bolling'): 1,
#           ('post', 'important'): 1,
#           ('important', 'note'): 2,
#           ('note', 'bolling'): 1,
#           ('bolling', 'summons'): 1,
#           ('summons', 'include'): 1,
#           ('include', 'huffpost'): 1,
#           ('huffpost', 'coming'): 1,
#           ('coming', 'personally'): 1,
#           ('personally', 'big'): 1,
#           ('big', 'boy'): 1,
#           ('boy', 'telling'): 1,
#           ('telling', 'https'): 1,
#           ('https', 'co'): 6,
#           ('co', 'nvludsiv87'): 2,
#           ('nvludsiv87', 'yashar'): 2,
#           ('august', 'going'): 1,
#           ('going', 'stop'): 1,
#           ('stop', 'reporting'): 1,
#           ('reporting', 'eric'): 1,
#           ('bolling', 'anyone'): 1,
#           ('anyone', 'else'): 1,
#           ('else', 'family'): 1,
#           ('family', 'members'): 1,
#           ('members', 'killed'): 1,
#           ('killed', 'jailed'): 1,
#           ('jailed', 'iran'): 1,
#           ('iran', 'lawsuit'): 1,
#           ('lawsuit', 'going'): 1,
#           ('going', 'scare'): 1,
#           ('scare', 'https'): 1,
#           ('august', 'nature'): 1,
#           ('nature', 'action'): 1,
#           ('action', 'damages'): 1,
#           ('damages', 'injunctive'): 1,
#           ('injunctive', 'relief'): 1,
#           ('relief', 'based'): 1,
#           ('based', 'defamation'): 1,
#           ('defamation', 'arising'): 1,
#           ('arising', 'defendant'): 1,
#           ('defendant', 'efforts'): 1,
#           ('efforts', 'injure'): 1,
#           ('injure', 'plaintiff'): 1,
#           ('plaintiff', 'reputation'): 1,
#           ('reputation', 'intentional'): 1,
#           ('intentional', 'highly'): 1,
#           ('highly', 'reckless'): 1,
#           ('reckless', 'publication'): 1,
#           ('publication', 'actionable'): 1,
#           ('actionable', 'false'): 1,
#           ('false', 'misleading'): 1,
#           ('misleading', 'statements'): 1,
#           ('statements', 'plaintiff'): 1,
#           ('plaintiff', 'conduct'): 1,
#           ('conduct', 'character'): 1,
#           ('character', 'result'): 1,
#           ('result', 'defendant'): 1,
#           ('defendant', 'actions'): 1,
#           ('actions', 'plaintiff'): 1,
#           ('plaintiff', 'substantially'): 1,
#           ('substantially', 'harmed'): 1,
#           ('harmed', 'reads'): 1,
#           ('reads', 'summons'): 1,
#           ('summons', 'sent'): 1,
#           ('sent', 'ali'): 1,
#           ('ali', 'editor'): 1,
#           ('editor', 'chief'): 1,
#           ('chief', 'huffington'): 1,
#           ('post', 'tweeted'): 1,
#           ('tweeted', 'outlet'): 1,
#           ('outlet', 'standing'): 1,
#           ('standing', 'ali'): 1,
#           ('ali', 'case'): 1,
#           ('case', 'yashar'): 1,
#           ('ali', 'paid'): 1,
#           ('paid', 'freelancer'): 1,
#           ('freelancer', 'contract'): 1,
#           ('contract', 'huffpost'): 1,
#           ('huffpost', 'hesitation'): 1,
#           ('hesitation', 'standing'): 1,
#           ('standing', 'financially'): 1,
#           ('financially', 'case'): 1,
#           ('case', 'lydia'): 1,
#           ('lydia', 'polgreen'): 1,
#           ('polgreen', 'lpolgreen'): 1,
#           ('lpolgreen', 'august'): 1,
#           ('august', 'huffpost'): 1,
#           ('huffpost', 'says'): 1,
#           ('says', 'hesitation'): 1,
#           ('hesitation', 'financially'): 1,
#           ('financially', 'stand'): 1,
#           ('stand', 'yashar'): 1,
#           ('yashar', 'ericbolling'): 1,
#           ('ericbolling', 'case'): 1,
#           ('case', 'hadas'): 1,
#           ('hadas', 'gold'): 1,
#           ('gold', 'hadas_gold'): 1,
#           ('hadas_gold', 'august'): 1,
#           ('august', 'friday'): 1,
#           ('friday', 'cruise'): 1,
#           ('cruise', 'ship'): 1,
#           ('ship', 'carrying'): 1,
#           ('carrying', 'around'): 1,
#           ('around', 'passengers'): 1,
#           ('passengers', 'dock'): 1,
#           ('dock', 'st'): 1,
#           ('st', 'john'): 1,
#           ('john', 'harbor'): 1,
#           ('harbor', 'caribbean'): 1,
#           ('caribbean', 'island'): 2,
#           ('island', 'antigua'): 2,
#           ('antigua', 'passengers'): 1,
#           ('passengers', 'expected'): 1,
#           ('expected', 'land'): 1,
#           ('land', 'booked'): 1,
#           ('booked', 'however'): 1,
#           ('however', 'carnival'): 1,
#           ('carnival', 'plc'): 1,
#           ('plc', 'ship'): 1,
#           ('ship', 'meant'): 1,
#           ('meant', 'dock'): 1,
#           ('dock', 'saint'): 1,
#           ('saint', 'martin'): 6,
#           ('martin', 'miles'): 1,
#           ('miles', 'km'): 1,
#           ('km', 'northwest'): 1,
#           ('northwest', 'however'): 1,
#           ('however', 'hurricane'): 1,
#           ('hurricane', 'irma'): 6,
#           ('irma', 'devastated'): 1,
#           ('devastated', 'island'): 1,
#           ('island', 'wrecking'): 1,
#           ('wrecking', 'port'): 1,
#           ('port', 'infrastructure'): 1,
#           ('infrastructure', 'leaving'): 1,
#           ('leaving', 'bounds'): 1,
#           ('bounds', 'tourists'): 1,
#           ('tourists', 'antiguan'): 1,
#           ('antiguan', 'officials'): 1,
#           ('officials', 'expect'): 1,
#           ('expect', 'carnival'): 1,
#           ('carnival', 'fascination'): 1,
#           ('fascination', 'visit'): 1,
#           ('visit', 'every'): 1,
#           ('every', 'friday'): 1,
#           ('friday', 'gotten'): 1,
#           ('gotten', 'calls'): 1,
#           ('calls', 'major'): 1,
#           ('major', 'cruise'): 1,
#           ('cruise', 'lines'): 4,
#           ('lines', 'royal'): 1,
#           ('royal', 'caribbean'): 1,
#           ('caribbean', 'cruises'): 1,
#           ('cruises', 'ltd'): 1,
#           ('ltd', 'norwegian'): 1,
#           ('norwegian', 'cruise'): 1,
#           ('lines', 'looking'): 1,
#           ('looking', 'make'): 1,
#           ('make', 'stops'): 1,
#           ('stops', 'end'): 1,
#           ('end', 'year'): 1,
#           ('year', 'asot'): 1,
#           ('asot', 'michael'): 1,
#           ('michael', 'antigua'): 1,
#           ('antigua', 'barbuda'): 1,
#           ('barbuda', 'minister'): 1,
#           ('minister', 'tourism'): 1,
#           ('tourism', 'unexpected'): 1,
#           ('unexpected', 'arrival'): 1,
#           ('arrival', 'thousands'): 1,
#           ('thousands', 'tourists'): 1,
#           ('tourists', 'bittersweet'): 1,
#           ('bittersweet', 'bonus'): 1,
#           ('bonus', 'going'): 1,
#           ('going', 'benefiting'): 1,
#           ('benefiting', 'want'): 1,
#           ('want', 'benefit'): 1,
#           ('benefit', 'others'): 1,
#           ('others', 'misfortune'): 1,
#           ('misfortune', 'disaster'): 1,
#           ('disaster', 'michael'): 1,
#           ('michael', 'said'): 1,
#           ('said', 'port'): 1,
#           ('port', 'damaged'): 1,
#           ('damaged', 'saint'): 1,
#           ('martin', 'damaged'): 1,
#           ('damaged', 'tortola'): 1,
#           ('tortola', 'british'): 1,
#           ('british', 'virgin'): 2,
#           ('virgin', 'islands'): 3,
#           ('islands', 'getting'): 1,
#           ('getting', 'cancellations'): 1,
#           ('cancellations', 'cruise'): 1,
#           ('lines', 'making'): 1,
#           ('making', 'ports'): 1,
#           ('ports', 'call'): 1,
#           ('call', 'antigua'): 1,
#           ('antigua', 'hurricane'): 1,
#           ('irma', 'left'): 1,
#           ('left', 'behind'): 1,
#           ('behind', 'stark'): 1,
#           ('stark', 'divide'): 1,
#           ('divide', 'caribbean'): 1,
#           ('caribbean', 'ahead'): 1,
#           ('ahead', 'winter'): 1,
#           ('winter', 'tourism'): 1,
#           ('tourism', 'season'): 2,
#           ('season', 'region'): 1,
#           ('region', 'economic'): 1,
#           ('economic', 'lifeblood'): 1,
#           ('lifeblood', 'travel'): 1,
#           ('travel', 'region'): 1,
#           ('region', 'picks'): 1,
#           ('picks', 'cruise'): 1,
#           ('lines', 'hotels'): 1,
#           ('hotels', 'airlines'): 1,
#           ('airlines', 'companies'): 1,
#           ('companies', 'directing'): 1,
#           ('directing', 'customers'): 1,
#           ('customers', 'places'): 1,
#           ('places', 'able'): 1,
#           ('able', 'host'): 1,
#           ('host', 'away'): 1,
#           ('away', 'worst'): 1,
#           ('worst', 'hit'): 3,
#           ('hit', 'areas'): 1,
#           ('areas', 'popular'): 1,
#           ('popular', 'winter'): 1,
#           ('winter', 'vacation'): 1,
#           ('vacation', 'spots'): 1,
#           ('spots', 'saint'): 1,
#           ('martin', 'british'): 1,
#           ('islands', 'saint'): 1,
#           ('saint', 'barthelemy'): 2,
#           ('barthelemy', 'devastated'): 1,
#           ('devastated', 'storm'): 1,
#           ('storm', 'could'): 1,
#           ('could', 'sidelined'): 1,
#           ('sidelined', 'weeks'): 1,
#           ('weeks', 'months'): 1,
#           ('months', 'million'): 1,
#           ('million', 'tourists'): 1,
#           ('tourists', 'visited'): 1,
#           ('visited', 'caribbean'): 1,
#           ('caribbean', 'spent'): 1,
#           ('spent', 'billion'): 1,
#           ('billion', 'new'): 1,
#           ('new', 'records'): 1,
#           ('records', 'according'): 1,
#           ('according', 'caribbean'): 1,
#           ('caribbean', 'tourism'): 1,
#           ('tourism', 'organization'): 1,
#           ('organization', 'saint'): 1,
#           ('martin', 'saint'): 1,
#           ('saint', 'bart'): 1,
#           ('bart', 'holiday'): 1,
#           ('holiday', 'season'): 1,
#           ('season', 'looks'): 1,
#           ('looks', 'compromised'): 1,
#           ('compromised', 'said'): 1,
#           ('said', 'jean'): 2,
#           ('jean', 'pierre'): 2,
#           ('pierre', 'mas'): 1,
#           ('mas', 'chairman'): 1,
#           ('chairman', 'french'): 1,
#           ('french', 'travel'): 1,
#           ('travel', 'agency'): 1,
#           ('agency', 'federation'): 1,
#           ('federation', 'snav'): 1,
#           ('snav', 'sentiment'): 1,
#           ('sentiment', 'winter'): 1,
#           ('winter', 'season'): 2,
#           ('season', 'lost'): 1,
#           ('lost', 'decisions'): 1,
#           ('decisions', 'book'): 1,
#           ('book', 'winter'): 1,
#           ('season', 'taken'): 1,
#           ('taken', 'right'): 1,
#           ('right', 'busy'): 1,
#           ('busy', 'tourist'): 1,
#           ('tourist', 'destinations'): 1,
#           ('destinations', 'western'): 1,
#           ('western', 'caribbean'): 1,
#           ('caribbean', 'barbados'): 1,
#           ('barbados', 'trinidad'): 2,
#           ('trinidad', 'well'): 1,
#           ('well', 'away'): 1,
#           ('away', 'path'): 1,
#           ('path', 'storm'): 1,
#           ('storm', 'cozumel'): 1,
#           ('cozumel', 'mexico'): 1,
#           ('mexico', 'gulf'): 1,
#           ('gulf', 'coast'): 1,
#           ('coast', 'got'): 1,
#           ('got', 'four'): 1,
#           ('four', 'additional'): 1,
#           ('additional', 'visits'): 1,
#           ('visits', 'week'): 1,
#           ('week', 'ships'): 1,
#           ('ships', 'rerouted'): 1,
#           ('rerouted', 'avoid'): 1,
#           ('avoid', 'storm'): 1,
#           ('storm', 'impact'): 1,
#           ('impact', 'although'): 1,
#           ('although', 'cozumel'): 1,
#           ('cozumel', 'tourism'): 1,
#           ('tourism', 'officials'): 1,
#           ('officials', 'said'): 7,
#           ('said', 'three'): 4,
#           ('three', 'cruises'): 1,
#           ('cruises', 'canceled'): 1,
#           ('canceled', 'florida'): 1,
#           ('florida', 'anticipating'): 1,
#           ('anticipating', 'another'): 1,
#           ('another', 'record'): 1,
#           ('record', 'year'): 1,
#           ('year', 'billion'): 1,
#           ('billion', 'year'): 1,
#           ('year', 'tourism'): 1,
#           ('tourism', 'industry'): 1,
#           ('industry', 'expected'): 1,
#           ('expected', 'rebound'): 1,
#           ('rebound', 'time'): 1,
#           ('time', 'peak'): 1,
#           ('peak', 'winter'): 1,
#           ('winter', 'travel'): 1,
#           ('travel', 'months'): 1,
#           ('months', 'moody'): 1,
#           ('moody', 'analytics'): 1,
#           ('analytics', 'said'): 1,
#           ('said', 'earlier'): 2,
#           ('earlier', 'week'): 2,
#           ('week', 'walt'): 1,
#           ('walt', 'disney'): 1,
#           ('disney', 'co'): 1,
#           ('co', 'reopened'): 1,
#           ('reopened', 'orlando'): 1,
#           ('orlando', 'disney'): 1,
#           ('disney', 'world'): 1,
#           ('world', 'theme'): 1,
#           ('theme', 'park'): 1,
#           ('park', 'sept'): 1,
#           ('sept', 'florida'): 1,
#           ('florida', 'keys'): 1,
#           ('keys', 'however'): 1,
#           ('however', 'wrestled'): 1,
#           ('wrestled', 'severe'): 1,
#           ('severe', 'storm'): 1,
#           ('storm', 'damage'): 1,
#           ('damage', 'nl2n1lr0n1'): 1,
#           ('nl2n1lr0n1', 'nf9n1l0029'): 1,
#           ('nf9n1l0029', 'nl2n1ls1hw'): 1,
#           ('nl2n1ls1hw', 'travel'): 1,
#           ('travel', 'companies'): 1,
#           ('companies', 'said'): 1,
#           ('said', 'still'): 1,
#           ('still', 'assessing'): 1,
#           ('assessing', 'situation'): 1,
#           ('situation', 'made'): 1,
#           ('made', 'firm'): 1,
#           ('firm', 'decisions'): 1,
#           ('decisions', 'rerouting'): 1,
#           ('rerouting', 'ships'): 1,
#           ('ships', 'tour'): 1,
#           ('tour', 'operator'): 1,
#           ('operator', 'virgin'): 1,
#           ('virgin', 'holidays'): 1,
#           ('holidays', 'said'): 1,
#           ('said', 'beginning'): 1,
#           ('beginning', 'return'): 1,
#           ('return', 'regular'): 1,
#           ('regular', 'operations'): 1,
#           ('operations', 'antigua'): 1,
#           ('antigua', 'despite'): 1,
#           ('despite', 'damage'): 1,
#           ('damage', 'properties'): 1,
#           ('properties', 'island'): 1,
#           ('antigua', 'badly'): 1,
#           ('badly', 'damaged'): 2,
#           ('damaged', 'feared'): 1,
#           ('feared', 'reopened'): 1,
#           ('reopened', 'tourism'): 1,
#           ('tourism', 'although'): 1,
#           ('although', 'three'): 1,
#           ('three', 'resorts'): 1,
#           ('resorts', 'currently'): 1,
#           ('currently', 'sale'): 1,
#           ('sale', 'damage'): 1,
#           ('damage', 'spokesman'): 1,
#           ('spokesman', 'virgin'): 1,
#           ('virgin', 'atlantic'): 1,
#           ('atlantic', 'said'): 1,
#           ('said', 'barbados'): 1,
#           ('trinidad', 'tobago'): 1,
#           ('tobago', 'st'): 1,
#           ('st', 'lucia'): 1,
#           ('lucia', 'three'): 1,
#           ('three', 'big'): 1,
#           ('big', 'tourist'): 1,
#           ('tourist', 'examples'): 1,
#           ('examples', 'impacted'): 1,
#           ('impacted', 'however'): 1,
#           ('however', 'small'): 1,
#           ('small', 'island'): 1,
#           ('island', 'saint'): 1,
#           ('martin', 'france'): 1,
#           ('france', 'shares'): 1,
#           ('shares', 'netherlands'): 1,
#           ('netherlands', 'could'): 1,
#           ('could', 'miss'): 1,
#           ('miss', 'much'): 1,
#           ('much', 'tourism'): 1,
#           ('season', 'french'): 1,
#           ('french', 'president'): 3,
#           ('president', 'emmanuel'): 3,
#           ('emmanuel', 'macron'): 3,
#           ('macron', 'wednesday'): 1,
#           ('wednesday', 'vowed'): 1,
#           ('vowed', 'swiftly'): 1,
#           ('swiftly', 'rebuild'): 1,
#           ('rebuild', 'islands'): 1,
#           ('islands', 'french'): 1,
#           ('french', 'caribbean'): 1,
#           ('caribbean', 'including'): 1,
#           ('including', 'saint'): 1,
#           ('martin', 'french'): 1,
#           ('french', 'public'): 1,
#           ('public', 'reinsurance'): 1,
#           ('reinsurance', 'body'): 1,
#           ('body', 'estimated'): 1,
#           ('estimated', 'cost'): 2,
#           ('cost', 'least'): 1,
#           ('least', 'billion'): 1,
#           ('billion', 'euros'): 1,
#           ('euros', 'billion'): 1,
#           ('billion', 'damage'): 1,
#           ('damage', 'saint'): 1,
#           ('barthelemy', 'nl2n1lt1sf'): 1,
#           ('nl2n1lt1sf', 'nl5n1lq09g'): 1,
#           ('nl5n1lq09g', 'hurricane'): 1,
#           ('irma', 'badly'): 1,
#           ('damaged', 'many'): 1,
#           ('many', 'hotels'): 1,
#           ('hotels', 'island'): 1,
#           ('island', 'accorhotels'): 1,
#           ('accorhotels', 'mercure'): 1,
#           ('mercure', 'hotel'): 1,
#           ('hotel', 'spokeswoman'): 1,
#           ('spokeswoman', 'accor'): 1,
#           ('accor', 'said'): 1,
#           ('said', 'nobody'): 1,
#           ('nobody', 'hurt'): 1,
#           ('hurt', 'hotel'): 1,
#           ('hotel', 'would'): 1,
#           ('would', 'closed'): 2,
#           ('closed', 'jan'): 1,
#           ('jan', 'least'): 1,
#           ('least', 'hotel'): 1,
#           ('hotel', 'rooms'): 1,
#           ('rooms', 'remain'): 1,
#           ('remain', 'operational'): 1,
#           ('operational', 'used'): 1,
#           ('used', 'house'): 1,
#           ('house', 'military'): 1,
#           ('military', 'forces'): 1,
#           ('forces', 'staff'): 1,
#           ('staff', 'supporting'): 1,
#           ('supporting', 'relief'): 1,
#           ('relief', 'effort'): 1,
#           ('effort', 'accorhotels'): 1,
#           ('accorhotels', 'offering'): 1,
#           ('offering', 'cancellation'): 1,
#           ('cancellation', 'reimbursement'): 1,
#           ('reimbursement', 'booked'): 1,
#           ('booked', 'stays'): 1,
#           ('stays', 'hotel'): 1,
#           ('hotel', 'washington'): 1,
#           ('washington', 'u'): 6,
#           ('u', 'senate'): 3,
#           ('senate', 'republican'): 2,
#           ('republican', 'leader'): 1,
#           ('leader', 'mitch'): 2,
#           ('mitch', 'mcconnell'): 2,
#           ('mcconnell', 'said'): 2,
#           ('said', 'thursday'): 4,
#           ('thursday', 'daca'): 1,
#           ('daca', 'program'): 1,
#           ('program', 'people'): 1,
#           ('people', 'arrived'): 1,
#           ('arrived', 'country'): 1,
#           ('country', 'illegally'): 1,
#           ('illegally', 'children'): 1,
#           ('children', 'part'): 1,
#           ('part', 'larger'): 1,
#           ('larger', 'discussion'): 1,
#           ('discussion', 'border'): 1,
#           ('border', 'security'): 2,
#           ('security', 'congress'): 1,
#           ('congress', 'would'): 2,
#           ('would', 'welcome'): 1,
#           ('welcome', 'proposal'): 1,
#           ('proposal', 'address'): 1,
#           ('address', 'issues'): 2,
#           ('issues', 'congress'): 1,
#           ('congress', 'debates'): 1,
#           ('debates', 'best'): 1,
#           ('best', 'ways'): 1,
#           ('ways', 'address'): 1,
#           ('address', 'illegal'): 1,
#           ('illegal', 'immigration'): 4,
#           ('immigration', 'strong'): 1,
#           ('strong', 'border'): 1,
#           ('security', 'interior'): 1,
#           ('interior', 'enforcement'): 1,
#           ('enforcement', 'daca'): 1,
#           ('daca', 'part'): 1,
#           ('part', 'discussions'): 1,
#           ('discussions', 'look'): 1,
#           ('forward', 'receiving'): 1,
#           ('receiving', 'trump'): 1,
#           ('trump', 'administration'): 18,
#           ('administration', 'legislative'): 1,
#           ('legislative', 'proposal'): 1,
#           ('proposal', 'continue'): 1,
#           ('continue', 'work'): 2,
#           ('work', 'issues'): 1,
#           ('issues', 'mcconnell'): 1,
#           ('said', 'statement'): 7,
#           ('statement', 'many'): 1,
#           ('many', 'times'): 2,
#           ('times', 'liberals'): 2,
#           ('liberals', 'used'): 1,
#           ('used', 'argument'): 1,
#           ('argument', 'everyone'): 1,
#           ('everyone', 'relatives'): 1,
#           ('relatives', 'came'): 1,
#           ('came', 'illegally'): 1,
#           ('illegally', 'answer'): 1,
#           ('answer', 'million'): 1,
#           ('million', 'times'): 1,
#           ('liberals', 'seem'): 1,
#           ('seem', 'differentiate'): 1,
#           ('differentiate', 'people'): 1,
#           ('people', 'came'): 1,
#           ('came', 'nation'): 1,
#           ('nation', 'either'): 1,
#           ('either', 'escape'): 1,
#           ('escape', 'persecution'): 1,
#           ('persecution', 'find'): 1,
#           ('find', 'better'): 1,
#           ('better', 'life'): 1,
#           ('life', 'came'): 1,
#           ('came', 'ellis'): 1,
#           ('ellis', 'island'): 1,
#           ('island', 'immediately'): 1,
#           ('immediately', 'applied'): 1,
#           ('applied', 'citizenship'): 1,
#           ('citizenship', 'america'): 1,
#           ('america', 'float'): 1,
#           ('float', 'across'): 1,
#           ('across', 'rio'): 1,
#           ('rio', 'grande'): 3,
#           ('grande', 'inner'): 1,
#           ('inner', 'tube'): 1,
#           ('tube', 'paying'): 1,
#           ('paying', 'coyote'): 1,
#           ('coyote', 'fee'): 1,
#           ('fee', 'help'): 1,
#           ('help', 'illegally'): 1,
#           ('illegally', 'cross'): 1,
#           ('cross', 'borders'): 1,
#           ('borders', 'meme'): 1,
#           ('meme', 'brilliantly'): 1,
#           ('brilliantly', 'explains'): 1,
#           ('explains', 'difference'): 1,
#           ('difference', 'short'): 1,
#           ('short', 'bullet'): 1,
#           ('bullet', 'points'): 1,
#           ('points', 'little'): 1,
#           ('little', 'visual'): 1,
#           ('visual', 'anyone'): 1,
#           ('anyone', 'tells'): 1,
#           ('tells', 'true'): 1,
#           ('true', 'estimated'): 1,
#           ('estimated', 'million'): 1,
#           ('million', 'illegal'): 2,
#           ('illegal', 'aliens'): 5,
#           ('aliens', 'currently'): 1,
#           ('currently', 'living'): 1,
#           ('living', 'united'): 1,
#           ('states', 'series'): 1,
#           ('series', 'visuals'): 1,
#           ('visuals', 'federation'): 1,
#           ('federation', 'american'): 1,
#           ('american', 'immigration'): 1,
#           ('immigration', 'reform'): 1,
#           ('reform', 'fair'): 1,
#           ('fair', 'help'): 1,
#           ('help', 'americans'): 1,
#           ('americans', 'understand'): 1,
#           ('understand', 'cost'): 1,
#           ('cost', 'illegal'): 2,
#           ('immigration', 'taxpaying'): 1,
#           ('taxpaying', 'americans'): 1,
#           ('americans', 'data'): 1,
#           ('data', 'september'): 1,
#           ('september', 'paints'): 1,
#           ('paints', 'pretty'): 1,
#           ('pretty', 'bleak'): 1,
#           ('bleak', 'economic'): 1,
#           ('economic', 'picture'): 1,
#           ('picture', 'america'): 1,
#           ('america', 'continue'): 1,
#           ('continue', 'ignore'): 1,
#           ('ignore', 'serious'): 1,
#           ('serious', 'problem'): 1,
#           ('problem', 'illegal'): 1,
#           ('immigration', 'fair'): 1,
#           ('fair', 'federal'): 1,
#           ('federal', 'state'): 1,
#           ('state', 'local'): 3,
#           ('local', 'levels'): 1,
#           ('levels', 'taxpayers'): 1,
#           ('taxpayers', 'shell'): 1,
#           ('shell', 'approximately'): 1,
#           ('approximately', 'billion'): 2,
#           ('billion', 'cover'): 1,
#           ('cover', 'costs'): 1,
#           ('costs', 'incurred'): 1,
#           ('incurred', 'presence'): 1,
#           ('presence', 'million'): 1,
#           ('aliens', 'million'): 1,
#           ('million', 'citizen'): 1,
#           ('citizen', 'children'): 1,
#           ('children', 'illegal'): 1,
#           ('aliens', 'amounts'): 1,
#           ('amounts', 'tax'): 1,
#           ('tax', 'burden'): 1,
#           ('burden', 'approximately'): 1,
#           ('approximately', 'per'): 1,
#           ('per', 'illegal'): 1,
#           ('illegal', 'alien'): 1,
#           ('alien', 'family'): 1,
#           ('family', 'member'): 2,
#           ('member', 'total'): 1,
#           ('total', 'total'): 1,
#           ('total', 'cost'): 2,
#           ('immigration', 'u'): 1,
#           ('u', 'taxpayers'): 1,
#           ('taxpayers', 'staggering'): 1,
#           ('staggering', 'crippling'): 1,
#           ('crippling', 'fair'): 1,
#           ('fair', 'estimated'): 1,
#           ('estimated', 'total'): 1,
#           ('cost', 'approximately'): 1,
#           ('billion', 'four'): 1,
#           ('four', 'years'): 3,
#           ('years', 'cost'): 1,
#           ('cost', 'risen'): 1,
#           ('risen', 'nearly'): 1,
#           ('nearly', 'billion'): 3,
#           ('billion', 'disturbing'): 1,
#           ('disturbing', 'unsustainable'): 1,
#           ('unsustainable', 'trend'): 1,
#           ('trend', 'hyderabad'): 1,
#           ('hyderabad', 'india'): 1,
#           ('india', 'u'): 1,
#           ('u', 'president'): 8,
#           ('president', 'donald'): 18,
#           ('donald', 'trump'): 70,
#           ('trump', 'daughter'): 1,
#           ('daughter', 'ivanka'): 1,
#           ('ivanka', 'trump'): 2,
#           ('trump', 'kicked'): 1,
#           ('kicked', 'global'): 1,
#           ('global', 'business'): 1,
#           ('business', 'summit'): 1,
#           ('summit', 'southern'): 1,
#           ('southern', 'india'): 1,
#           ('india', 'tuesday'): 1,
#           ('tuesday', 'calling'): 1,
#           ('calling', 'better'): 1,
#           ('better', 'opportunities'): 1,
#           ('opportunities', 'women'): 2,
#           ('women', 'entrepreneurs'): 2,
#           ('entrepreneurs', 'battling'): 1,
#           ('battling', 'heavy'): 1,
#           ('heavy', 'odds'): 1,
#           ('odds', 'around'): 1,
#           ('around', 'world'): 4,
#           ('world', 'ivanka'): 1,
#           ('ivanka', 'also'): 1,
#           ('also', 'informal'): 1,
#           ('informal', 'adviser'): 1,
#           ('adviser', 'father'): 1,
#           ('father', 'received'): 1,
#           ('received', 'warm'): 1,
#           ('warm', 'welcome'): 1,
#           ('welcome', 'india'): 1,
#           ('india', 'high'): 1,
#           ('high', 'tech'): 1,
#           ('tech', 'hub'): 1,
#           ('hub', 'hyderabad'): 1,
#           ('hyderabad', 'trappings'): 1,
#           ('trappings', 'state'): 1,
#           ('state', 'guest'): 1,
#           ('guest', 'prime'): 1,
#           ('minister', 'narendra'): 3,
#           ('narendra', 'modi'): 3,
#           ('modi', 'joined'): 1,
#           ('joined', 'opening'): 1,
#           ('opening', 'u'): 1,
#           ('u', 'backed'): 1,
#           ('backed', 'global'): 1,
#           ('global', 'entrepreneurship'): 1,
#           ('entrepreneurship', 'summit'): 1,
#           ('summit', 'new'): 1,
#           ...})]

# %%
def joining_words(news):
    newss = " ".join(str(i) for i in news) # Convert to string
    return newss

# %%
df_sample['text'] = df_sample['text'].apply(joining_words)
df_sample['title'] = df_sample['title'].apply(joining_words)
df_sample
# Out:
#                                                    title  \
# 41972  cambodia detained opposition leader denies tre...
# 10186  boom fox news host eric bolling hits back mill...
# 43521  irma creates bittersweet travel bonus luckier ...
# 25221  senate republican leader says daca part border...
# 9742   4 easy understand reasons ancestors illegals c...
# ...                                                  ...
# 13501  ha angry feminist senator attacks trump pence ...
# 7064   study shows profound negative impact religion ...
# 3532                carrier workers blast trump lied ass
# 14153             uh oh bill clinton unloads obama video
# 34086  connecticut cancels pay raises managers budget...
#
#                                                     text       subject  \
# 41972  phnom penh cambodia detained opposition leader...     worldnews
# 10186  bolling tweeted couple messages thanking suppo...      politics
# 43521  friday cruise ship carrying around passengers ...     worldnews
# 25221  washington u senate republican leader mitch mc...  politicsNews
# 9742   many times liberals used argument everyone rel...      politics
# ...                                                  ...           ...
# 13501  certainly hope hillary picks liz warren vp mis...      politics
# 7064   matter much republicans fox news say otherwise...          News
# 3532   donald trump bragging nonstop carrier deal sup...          News
# 14153  unlike president lot things coming apart aroun...      politics
# 34086  new york connecticut cancel pay raises manager...  politicsNews
#
#          date  category
# 41972  736604         1
# 10186  736550         0
# 43521  736586         1
# 25221  736586         1
# 9742   736607         0
# ...       ...       ...
# 13501  736161         0
# 7064   736060         0
# 3532   736304         0
# 14153  736061         0
# 34086  736023         1
#
# [100 rows x 5 columns]

# %%
df_sample["length_text"] = [len(word.split()) for word in df_sample["text"]]
df_sample
# Out:
#                                                    title  \
# 41972  cambodia detained opposition leader denies tre...
# 10186  boom fox news host eric bolling hits back mill...
# 43521  irma creates bittersweet travel bonus luckier ...
# 25221  senate republican leader says daca part border...
# 9742   4 easy understand reasons ancestors illegals c...
# ...                                                  ...
# 13501  ha angry feminist senator attacks trump pence ...
# 7064   study shows profound negative impact religion ...
# 3532                carrier workers blast trump lied ass
# 14153             uh oh bill clinton unloads obama video
# 34086  connecticut cancels pay raises managers budget...
#
#                                                     text       subject  \
# 41972  phnom penh cambodia detained opposition leader...     worldnews
# 10186  bolling tweeted couple messages thanking suppo...      politics
# 43521  friday cruise ship carrying around passengers ...     worldnews
# 25221  washington u senate republican leader mitch mc...  politicsNews
# 9742   many times liberals used argument everyone rel...      politics
# ...                                                  ...           ...
# 13501  certainly hope hillary picks liz warren vp mis...      politics
# 7064   matter much republicans fox news say otherwise...          News
# 3532   donald trump bragging nonstop carrier deal sup...          News
# 14153  unlike president lot things coming apart aroun...      politics
# 34086  new york connecticut cancel pay raises manager...  politicsNews
#
#          date  category  length_text
# 41972  736604         1          202
# 10186  736550         0          227
# 43521  736586         1          396
# 25221  736586         1           55
# 9742   736607         0          147
# ...       ...       ...          ...
# 13501  736161         0           92
# 7064   736060         0          247
# 3532   736304         0          180
# 14153  736061         0          123
# 34086  736023         1          167
#
# [100 rows x 6 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
plt.figure(figsize = (20,20)) # Text from the real news articles
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(" ".join(df_sample[df_sample.category == 1].text))
plt.imshow(wc , interpolation = 'bilinear')
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# contador = []
# for i in df_sample["text"]:
#     count = list(bigrams(i))
#     contador.append(Counter(count))
# contador
