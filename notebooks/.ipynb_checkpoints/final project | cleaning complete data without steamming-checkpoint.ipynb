# %% [markdown]
# <img src="../images/fake-news-quotes-01-830x467.jpeg" width="800" height="70" />

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.util import bigrams
from nltk.stem import PorterStemmer

import re
import datetime
# Out:
# [nltk_data] Downloading package stopwords to /Users/kilo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 1. Get data
# [data source](https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset)

# %%
df_0 = pd.read_csv("../data/archive/Fake.csv")
df_1 = pd.read_csv("../data/archive/True.csv")

# %% [markdown]
# ### 1. EDA

# %% [markdown]
# <img src="../images/Screenshot 2021-05-17 at 16.24.54.png
# " width="300" height="50" />

# %%
df_0.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_1.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
# adding category 0 to fake news and category 1 to true news
df_0["category"] = 0
df_1["category"] = 1

# %%
# concatenating dataframes
df = pd.concat([df_0, df_1],axis=0)
df = df.reset_index()
df = df.drop(['index'], axis=1)
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 44895  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  category
# 0      December 31, 2017         0
# 1      December 31, 2017         0
# 2      December 30, 2017         0
# 3      December 29, 2017         0
# 4      December 25, 2017         0
# ...                  ...       ...
# 44893   August 22, 2017          1
# 44894   August 22, 2017          1
# 44895   August 22, 2017          1
# 44896   August 22, 2017          1
# 44897   August 22, 2017          1
#
# [44898 rows x 5 columns]

# %%
# saving dataframe as CSV
df.to_csv(f'../data/df_fakenews_merge.csv', index=False)

# %%
# quick overview of the new dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     44898 non-null  object
#  1   text      44898 non-null  object
#  2   subject   44898 non-null  object
#  3   date      44898 non-null  object
#  4   category  44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
# Return the number of missing values in each column
df.isnull( ).sum( )
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# Number of unique elements in "subjetc" column
df["subject"].unique()
# Out:
# array(['News', 'politics', 'Government News', 'left-news', 'US_News',
#        'Middle-east', 'politicsNews', 'worldnews'], dtype=object)

# %%
# Statistical summary for numerical columns present in the dataset. 
# Not to much sense on this dataframe
df.describe()
# Out:
#            category
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
# getting number of dimensions as well as the size in each dimension
df.shape
# Out:
# (44898, 5)

# %%
# Ploting a first overview of the data
plt.figure(figsize=(13,5))
sns.countplot(x='subject', data=df, hue='category', color='#042f66')

plt.title('Article subjects by category', fontsize=24)
plt.ylabel('Total', fontsize=14)
plt.xlabel("")
plt.xticks(fontsize=14)
sns.set_style("dark")
plt.legend(['Real', 'Fake'])
plt.show()

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# <img src="../images/data_cleaning.jpeg" width="300" height="50" />

# %%
# Detect missing values for an array-like object.
df.isnull().sum()
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# removing a row that has a NaN or missing values in it.
df.dropna(inplace=True)

# %%
# analyzing duplicated values
df.duplicated().sum()
# Out:
# 209

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# counting duplicated rows in "title" column
df["title"].duplicated().sum()
# Out:
# 5960

# %%
df["text"].duplicated().sum()
# Out:
# 6043

# %% [markdown]
# ---------------

# %% [markdown]
# ##### I want to see how many duplicated "titles" and "texts" belong to fake_news

# %%
df_0["title"].duplicated().sum()
# Out:
# 5578

# %%
df_0["text"].duplicated().sum()
# Out:
# 6026

# %% [markdown]
# Most of the duplicated rows belong to fake news..... maybe this goes back to the need to repeat a message to reaffirm it or probably as well to the weak imagination of the inventors of lies.

# %% [markdown]
# -------

# %%
# drop duplicated rows on "text" column
df = df.drop_duplicates(subset=['text'])

# %%
# drop duplicated rows on "title" column
df = df.drop_duplicates(subset=['title'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38270 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     38270 non-null  object
#  1   text      38270 non-null  object
#  2   subject   38270 non-null  object
#  3   date      38270 non-null  object
#  4   category  38270 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.8+ MB

# %%
# setting up the function to work on the sample and later work with the whole dataframe.
from nltk.corpus import stopwords
ps = PorterStemmer()
en_stops = stopwords.words('english')
us_stops = stopwords.words('english')
us_stops.append("us")
us_stops.append("would")

def stopwords(news):
    new_news = []
    # despues de haber hecho el stopword solo al final vi q me volvian a quedar algunas palabras sueltas, entonces decidi hacer una pasada antes y luego otra al final
    news = news.lower().split()
    news = [word for word in news if not word in us_stops]
    news = " ".join(str(i) for i in news)
    news = re.sub(r'\$[^\s]+', 'dollar', news) # changing sign $ per dollar word
    news = re.sub('https?://\S+|www\.\S+', '', news) # removing link of web page from string
    news = re.sub(r'[^\w\s]+',"",news) # removing characters
    news = re.sub(" \d+", " ", news) # removing digits
    news = re.sub(r'(?:^| )\w(?:$| )', ' ', news) # removing any single letter on a string 
    news = re.sub("reuters","", news) 
    #news = re.sub(r'https?:\/\/\S+','',news)#remove the hyperlink
    #news = re.sub(r'[^a-z\.\s]', "" , news) # removing everything that is not 
    #news = re.sub(r'http\S+', '', news) # removing link of web page from string
    # news = re.sub('https?://\S+|www\.\S+', '', news) # removing link of web page from string
    #news = re.sub(r'https?:\/\/\S+','',news)#remove the hyperlink
    news = news.split((" "))
    news = list(map(lambda x: ps.stem(x),news)) # using PorterStemmer to get the standar version of some words (example: working= work, worked= work)
    news = [word for word in news if not word in en_stops]
    news = " ".join(str(i) for i in news)
    return news

# %%
df['text'] = df['text'].apply(stopwords)
df['title'] = df['title'].apply(stopwords)
df
# Out:
#                                                    title  \
# 0      donald trump send embarrass new year eve messa...
# 1      drunk brag trump staffer start russian collus ...
# 2      sheriff david clark becom internet joke threat...
# 3          trump obsess even obama name code websit imag
# 4          pope franci call donald trump christma speech
# ...                                                  ...
# 44892  north korea shipment syria chemic arm agenc in...
# 44894       lexisnexi withdrew two product chines market
# 44895                      minsk cultur hub becom author
# 44896    vatican upbeat possibl pope franci visit russia
# 44897     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject  \
# 0      donald trump wish american happi new year leav...       News
# 1      hous intellig committe chairman devin nune go ...       News
# 2      friday reveal former milwauke sheriff david cl...       News
# 3      christma day donald trump announc back work fo...       News
# 4      pope franci use annual christma day messag reb...       News
# ...                                                  ...        ...
# 44892  unit nation   two north korean shipment syrian...  worldnews
# 44894  london   lexisnexi provid legal regulatori bus...  worldnews
# 44895  minsk   shadow disus sovietera factori minsk s...  worldnews
# 44896  moscow   vatican secretari state cardin pietro...  worldnews
# 44897  jakarta   indonesia buy  sukhoi fighter jet wo...  worldnews
#
#                     date  category
# 0      December 31, 2017         0
# 1      December 31, 2017         0
# 2      December 30, 2017         0
# 3      December 29, 2017         0
# 4      December 25, 2017         0
# ...                  ...       ...
# 44892   August 21, 2017          1
# 44894   August 22, 2017          1
# 44895   August 22, 2017          1
# 44896   August 22, 2017          1
# 44897   August 22, 2017          1
#
# [38270 rows x 5 columns]

# %% [markdown]
# #### Now I goint to work on the date column

# %%
# there some rows that have another information but not date-info I will delete them
df = df[df['date'].str.len() < 22]

# %%
def date_time(dtime):
    print("object type: ",dtime.dtype)
    dtime =pd.to_datetime(dtime) # convert it to datetime
    print("object type: ",dtime.dtype) # check datatype again
    print("min time: ",dtime.min()) # check when data begin
    print("max time: ",dtime.max()) # check when data end
    dtime = dtime.apply(lambda x: x.toordinal()) # we will change the effective to date column to ordinal
    return dtime
df['date'] = date_time(df['date'])
# Out:
# object type:  object
# object type:  datetime64[ns]
# min time:  2015-03-31 00:00:00
# max time:  2018-02-19 00:00:00

# %%
def split_words(news):
    news = news.split()
    return news

# %%
df['text'] = df['text'].apply(split_words)
df['title'] = df['title'].apply(split_words)
df
# Out:
#                                                    title  \
# 0      [donald, trump, send, embarrass, new, year, ev...
# 1      [drunk, brag, trump, staffer, start, russian, ...
# 2      [sheriff, david, clark, becom, internet, joke,...
# 3      [trump, obsess, even, obama, name, code, websi...
# 4      [pope, franci, call, donald, trump, christma, ...
# ...                                                  ...
# 44892  [north, korea, shipment, syria, chemic, arm, a...
# 44894  [lexisnexi, withdrew, two, product, chines, ma...
# 44895                [minsk, cultur, hub, becom, author]
# 44896  [vatican, upbeat, possibl, pope, franci, visit...
# 44897  [indonesia, buy, dollar, billion, worth, russi...
#
#                                                     text    subject    date  \
# 0      [donald, trump, wish, american, happi, new, ye...       News  736694
# 1      [hous, intellig, committe, chairman, devin, nu...       News  736694
# 2      [friday, reveal, former, milwauke, sheriff, da...       News  736693
# 3      [christma, day, donald, trump, announc, back, ...       News  736692
# 4      [pope, franci, use, annual, christma, day, mes...       News  736688
# ...                                                  ...        ...     ...
# 44892  [unit, nation, two, north, korean, shipment, s...  worldnews  736562
# 44894  [london, lexisnexi, provid, legal, regulatori,...  worldnews  736563
# 44895  [minsk, shadow, disus, sovietera, factori, min...  worldnews  736563
# 44896  [moscow, vatican, secretari, state, cardin, pi...  worldnews  736563
# 44897  [jakarta, indonesia, buy, sukhoi, fighter, jet...  worldnews  736563
#
#        category
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 44892         1
# 44894         1
# 44895         1
# 44896         1
# 44897         1
#
# [38264 rows x 5 columns]

# %%
# to detect the most repeated keywords in df_sample'text'.
words = [wrd for x in df['text'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_text = Counter(words)
keywords_text = pd.DataFrame.from_dict(keywords_text, orient='index').reset_index()
keywords_text = keywords_text.sort_values(by=[0], ascending=False)
keywords_text.columns = ['word','count']
keywords_text.head(60)
# Out:
#             word   count
# 242         said  118908
# 1          trump  116106
# 248        state   52299
# 33        presid   48346
# 160           us   44072
# 80         peopl   35645
# 785   republican   35446
# 90           say   31306
# 21           one   30954
# 6           year   29813
# 68          also   26695
# 5            new   26505
# 1577      govern   26000
# 150         hous   25571
# 0         donald   24989
# 47          like   24843
# 251     democrat   24282
# 216        elect   23844
# 247       report   23167
# 578       nation   22928
# 356         time   22859
# 239      clinton   22436
# 577         unit   21982
# 30       support   21850
# 465        obama   21833
# 23       countri   21539
# 311         call   21122
# 729        could   20990
# 611        parti   20715
# 180     campaign   20709
# 998        senat   20647
# 1209        told   20364
# 156           go   20209
# 137         vote   19871
# 67          make   19840
# 757        white   19436
# 797       dollar   19079
# 231       offici   18934
# 123         last   18396
# 3       american   18346
# 341        right   17659
# 332          get   17338
# 214          two   17274
# 78        includ   17176
# 86           use   16939
# 28          want   16781
# 824        polit   16556
# 115         work   16247
# 1015       group   16180
# 770         take   16169
# 750        offic   15978
# 31          even   15851
# 486   washington   15620
# 15          news   15611
# 1389         law   15580
# 1018       first   15571
# 284        secur   15402
# 17        former   14959
# 782         week   14612
# 158          day   14341

# %%
# to detect the most repeated keywords in df_sample'title'.
words = [wrd for x in df['title'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_title = Counter(words)
keywords_title = pd.DataFrame.from_dict(keywords_title, orient='index').reset_index()
keywords_title = keywords_title.sort_values(by=[0], ascending=False)
keywords_title.columns = ['word','count']
keywords_title.head(60)
# Out:
#             word  count
# 1          trump  12415
# 150        video   5967
# 258           us   4168
# 104          say   3800
# 28         obama   2288
# 187         hous   1878
# 151   republican   1748
# 74         watch   1577
# 148        senat   1536
# 4            new   1502
# 186        white   1453
# 792      hillari   1452
# 136       presid   1435
# 810      clinton   1421
# 35          call   1233
# 100        state   1175
# 123         bill   1142
# 293       russia   1137
# 890         vote   1113
# 182     democrat   1108
# 152          get    997
# 296        elect    962
# 243      support    947
# 73         tweet    943
# 1606       north    937
# 310        court    924
# 274       attack    919
# 1607       korea    870
# 269         plan    862
# 81          make    819
# 122          tax    797
# 0         donald    786
# 450       report    767
# 221        break    764
# 2826       china    756
# 900         kill    745
# 101         news    737
# 341       leader    729
# 119          gop    729
# 507         talk    705
# 1734        meet    702
# 266         want    701
# 197     campaign    701
# 544         deal    696
# 42         black    696
# 291       offici    694
# 62          back    672
# 1390         may    668
# 319         show    646
# 686        polic    642
# 110        media    636
# 702       dollar    624
# 2027      muslim    620
# 162        parti    614
# 284         take    610
# 13       russian    599
# 875      protest    588
# 1301        iran    580
# 5648          eu    571
# 513         rule    567

# %%
df.head(5)
# Out:
#                                                title  \
# 0  [donald, trump, send, embarrass, new, year, ev...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, internet, joke,...
# 3  [trump, obsess, even, obama, name, code, websi...
# 4  [pope, franci, call, donald, trump, christma, ...
#
#                                                 text subject    date  category
# 0  [donald, trump, wish, american, happi, new, ye...    News  736694         0
# 1  [hous, intellig, committe, chairman, devin, nu...    News  736694         0
# 2  [friday, reveal, former, milwauke, sheriff, da...    News  736693         0
# 3  [christma, day, donald, trump, announc, back, ...    News  736692         0
# 4  [pope, franci, use, annual, christma, day, mes...    News  736688         0

# %%
def joining_list(news):
    news = " ".join(str(i) for i in news) # Convert to string
    return news

# %%
df['text'] = df['text'].apply(joining_list)
df['title'] = df['title'].apply(joining_list)
df
# Out:
#                                                    title  \
# 0      donald trump send embarrass new year eve messa...
# 1      drunk brag trump staffer start russian collus ...
# 2      sheriff david clark becom internet joke threat...
# 3          trump obsess even obama name code websit imag
# 4          pope franci call donald trump christma speech
# ...                                                  ...
# 44892  north korea shipment syria chemic arm agenc in...
# 44894       lexisnexi withdrew two product chines market
# 44895                      minsk cultur hub becom author
# 44896    vatican upbeat possibl pope franci visit russia
# 44897     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject    date  \
# 0      donald trump wish american happi new year leav...       News  736694
# 1      hous intellig committe chairman devin nune go ...       News  736694
# 2      friday reveal former milwauke sheriff david cl...       News  736693
# 3      christma day donald trump announc back work fo...       News  736692
# 4      pope franci use annual christma day messag reb...       News  736688
# ...                                                  ...        ...     ...
# 44892  unit nation two north korean shipment syrian g...  worldnews  736562
# 44894  london lexisnexi provid legal regulatori busi ...  worldnews  736563
# 44895  minsk shadow disus sovietera factori minsk str...  worldnews  736563
# 44896  moscow vatican secretari state cardin pietro p...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jet worth...  worldnews  736563
#
#        category
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 44892         1
# 44894         1
# 44895         1
# 44896         1
# 44897         1
#
# [38264 rows x 5 columns]

# %%
df["length_text"] = [len(word.split()) for word in df["text"]]
df["length_title"] = [len(word.split()) for word in df["title"]]
df
# Out:
#                                                    title  \
# 0      donald trump send embarrass new year eve messa...
# 1      drunk brag trump staffer start russian collus ...
# 2      sheriff david clark becom internet joke threat...
# 3          trump obsess even obama name code websit imag
# 4          pope franci call donald trump christma speech
# ...                                                  ...
# 44892  north korea shipment syria chemic arm agenc in...
# 44894       lexisnexi withdrew two product chines market
# 44895                      minsk cultur hub becom author
# 44896    vatican upbeat possibl pope franci visit russia
# 44897     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject    date  \
# 0      donald trump wish american happi new year leav...       News  736694
# 1      hous intellig committe chairman devin nune go ...       News  736694
# 2      friday reveal former milwauke sheriff david cl...       News  736693
# 3      christma day donald trump announc back work fo...       News  736692
# 4      pope franci use annual christma day messag reb...       News  736688
# ...                                                  ...        ...     ...
# 44892  unit nation two north korean shipment syrian g...  worldnews  736562
# 44894  london lexisnexi provid legal regulatori busi ...  worldnews  736563
# 44895  minsk shadow disus sovietera factori minsk str...  worldnews  736563
# 44896  moscow vatican secretari state cardin pietro p...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jet worth...  worldnews  736563
#
#        category  length_text  length_title
# 0             0          255             9
# 1             0          178             8
# 2             0          315            10
# 3             0          238             8
# 4             0          208             7
# ...         ...          ...           ...
# 44892         1          275            10
# 44894         1           73             6
# 44895         1          169             5
# 44896         1          116             7
# 44897         1          136             7
#
# [38264 rows x 7 columns]

# %%
print(df.iloc[6,1])
# Out:
# donald trump spent good portion day golf club mark th day done sinc take oath offic must bad game trump lash fbi deputi director andrew mccabe twitter follow report say mccabe plan retir month report follow mccabe testimoni front congression committe week well mount critic republican regard russia probeso natur trump attack mccabe lie fbi deputi director andrew mccabe man charg along leakin jame comey phoni hillari clinton investig includ illeg delet email given dollar wife campaign clinton puppet investig trump tweetedhow fbi deputi director andrew mccabe man charg along leakin jame comey phoni hillari clinton investig includ illeg delet email given dollar wife campaign clinton puppet investig donald trump realdonaldtrump decemb stop therefbi deputi director andrew mccabe race clock retir full benefit day go donald trump realdonaldtrump decemb wow fbi lawyer jame baker reassign accord foxnew donald trump realdonaldtrump decemb intel trump dispos get inform fox news mccabe spent career fight terror attack socal presid trump factcheck claim wife receiv dollar campaignpolitifact note late juli trump tweet andrew mccabe signific distort fact implic mccabe got clinton polit favor make much sens look evid juli tweet rate mostli fals trump repeat lie know support believ without bother googl still lie thoughphoto zach gibson poolgetti imag

# %%
df = df[df['text'].notnull()]
df
# Out:
#                                                    title  \
# 0      donald trump send embarrass new year eve messa...
# 1      drunk brag trump staffer start russian collus ...
# 2      sheriff david clark becom internet joke threat...
# 3          trump obsess even obama name code websit imag
# 4          pope franci call donald trump christma speech
# ...                                                  ...
# 44892  north korea shipment syria chemic arm agenc in...
# 44894       lexisnexi withdrew two product chines market
# 44895                      minsk cultur hub becom author
# 44896    vatican upbeat possibl pope franci visit russia
# 44897     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject    date  \
# 0      donald trump wish american happi new year leav...       News  736694
# 1      hous intellig committe chairman devin nune go ...       News  736694
# 2      friday reveal former milwauke sheriff david cl...       News  736693
# 3      christma day donald trump announc back work fo...       News  736692
# 4      pope franci use annual christma day messag reb...       News  736688
# ...                                                  ...        ...     ...
# 44892  unit nation two north korean shipment syrian g...  worldnews  736562
# 44894  london lexisnexi provid legal regulatori busi ...  worldnews  736563
# 44895  minsk shadow disus sovietera factori minsk str...  worldnews  736563
# 44896  moscow vatican secretari state cardin pietro p...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jet worth...  worldnews  736563
#
#        category  length_text  length_title
# 0             0          255             9
# 1             0          178             8
# 2             0          315            10
# 3             0          238             8
# 4             0          208             7
# ...         ...          ...           ...
# 44892         1          275            10
# 44894         1           73             6
# 44895         1          169             5
# 44896         1          116             7
# 44897         1          136             7
#
# [38264 rows x 7 columns]

# %%
df = df[df['text'].notnull()]
df = df.dropna()
df
# Out:
#                                                    title  \
# 0      donald trump send embarrass new year eve messa...
# 1      drunk brag trump staffer start russian collus ...
# 2      sheriff david clark becom internet joke threat...
# 3          trump obsess even obama name code websit imag
# 4          pope franci call donald trump christma speech
# ...                                                  ...
# 44892  north korea shipment syria chemic arm agenc in...
# 44894       lexisnexi withdrew two product chines market
# 44895                      minsk cultur hub becom author
# 44896    vatican upbeat possibl pope franci visit russia
# 44897     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject    date  \
# 0      donald trump wish american happi new year leav...       News  736694
# 1      hous intellig committe chairman devin nune go ...       News  736694
# 2      friday reveal former milwauke sheriff david cl...       News  736693
# 3      christma day donald trump announc back work fo...       News  736692
# 4      pope franci use annual christma day messag reb...       News  736688
# ...                                                  ...        ...     ...
# 44892  unit nation two north korean shipment syrian g...  worldnews  736562
# 44894  london lexisnexi provid legal regulatori busi ...  worldnews  736563
# 44895  minsk shadow disus sovietera factori minsk str...  worldnews  736563
# 44896  moscow vatican secretari state cardin pietro p...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jet worth...  worldnews  736563
#
#        category  length_text  length_title
# 0             0          255             9
# 1             0          178             8
# 2             0          315            10
# 3             0          238             8
# 4             0          208             7
# ...         ...          ...           ...
# 44892         1          275            10
# 44894         1           73             6
# 44895         1          169             5
# 44896         1          116             7
# 44897         1          136             7
#
# [38264 rows x 7 columns]

# %%
# saving dataframe as CSV
df.to_csv(f'../data/df_fake_news.csv', index=False)
