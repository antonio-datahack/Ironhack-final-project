# %% [markdown]
# <img src="../images/fake-news-quotes-01-830x467.jpeg" width="800" height="70" />

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

import re
import datetime
# Out:
# [nltk_data] Downloading package stopwords to /Users/kilo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 1. Get data
# [data source](https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset)

# %%
df_0 = pd.read_csv("../data/archive/Fake.csv")
df_1 = pd.read_csv("../data/archive/True.csv")

# %% [markdown]
# ### 1. EDA

# %% [markdown]
# <img src="../images/Screenshot 2021-05-17 at 16.24.54.png
# " width="300" height="50" />

# %%
df_0.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_1.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
# adding category 0 to fake news and category 1 to true news
df_0["category"] = 0
df_1["category"] = 1

# %%
# concatenating dataframes
df = pd.concat([df_0, df_1],axis=0)
df = df.reset_index()
df = df.drop(['index'], axis=1)
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 44895  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  category
# 0      December 31, 2017         0
# 1      December 31, 2017         0
# 2      December 30, 2017         0
# 3      December 29, 2017         0
# 4      December 25, 2017         0
# ...                  ...       ...
# 44893   August 22, 2017          1
# 44894   August 22, 2017          1
# 44895   August 22, 2017          1
# 44896   August 22, 2017          1
# 44897   August 22, 2017          1
#
# [44898 rows x 5 columns]

# %%
# saving dataframe as CSV
df.to_csv(f'../data/df_fakenews_merge.csv', index=False)

# %%
# quick overview of the new dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     44898 non-null  object
#  1   text      44898 non-null  object
#  2   subject   44898 non-null  object
#  3   date      44898 non-null  object
#  4   category  44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
# Return the number of missing values in each column
df.isnull( ).sum( )
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# Number of unique elements in "subjetc" column
df["subject"].unique()
# Out:
# array(['News', 'politics', 'Government News', 'left-news', 'US_News',
#        'Middle-east', 'politicsNews', 'worldnews'], dtype=object)

# %%
# Statistical summary for numerical columns present in the dataset. 
# Not to much sense on this dataframe
df.describe()
# Out:
#            category
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
# getting number of dimensions as well as the size in each dimension
df.shape
# Out:
# (44898, 5)

# %%
# Ploting a first overview of the data
plt.figure(figsize=(13,5))
sns.countplot(x='subject', data=df, hue='category', color='#042f66')

plt.title('Article subjects by category', fontsize=24)
plt.ylabel('Total', fontsize=14)
plt.xlabel("")
plt.xticks(fontsize=14)
sns.set_style("dark")
plt.legend(['Real', 'Fake'])
plt.show()

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# <img src="../images/data_cleaning.jpeg" width="300" height="50" />

# %%
# Detect missing values for an array-like object.
df.isnull().sum()
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %%
# removing a row that has a NaN or missing values in it.
df.dropna(inplace=True)

# %%
# analyzing duplicated values
df.duplicated().sum()
# Out:
# 209

# %%
# drop duplicates
df = df.drop_duplicates()

# %%
# counting duplicated rows in "title" column
df["title"].duplicated().sum()
# Out:
# 5960

# %%
df["text"].duplicated().sum()
# Out:
# 6043

# %% [markdown]
# ---------------

# %% [markdown]
# ##### I want to see how many duplicated "titles" and "texts" belong to fake_news

# %%
df_0["title"].duplicated().sum()
# Out:
# 5578

# %%
df_0["text"].duplicated().sum()
# Out:
# 6026

# %% [markdown]
# Most of the duplicated rows belong to fake news..... maybe this goes back to the need to repeat a message to reaffirm it or probably as well to the weak imagination of the inventors of lies.

# %% [markdown]
# -------

# %%
# drop duplicated rows on "text" column
df = df.drop_duplicates(subset=['text'])

# %%
# drop duplicated rows on "title" column
df = df.drop_duplicates(subset=['title'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38270 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     38270 non-null  object
#  1   text      38270 non-null  object
#  2   subject   38270 non-null  object
#  3   date      38270 non-null  object
#  4   category  38270 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.8+ MB

# %%
# setting up the function to work on the sample and later work with the whole dataframe.
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

def stopwords(news):
    new_news = []
    news = news.lower()
    news = re.sub(r'[^\w\s]+'," ",news) # removing characters
    news = re.sub('https?://\S+|www\.\S+', '', news) # removing link of web page from string
    news = re.sub(" \d+", " ", news) # removing digits
    news = re.sub(r'(?:^| )\w(?:$| )', ' ', news) # removing any single letter on a string in python
    news = re.sub("reuters","", news) 
    for word in news.split():
        if word not in en_stops:
            new_news.append(word)
    news = " ".join(str(i) for i in new_news)
    return news

# %%
df['text'] = df['text'].apply(stopwords)
df['title'] = df['title'].apply(stopwords)
df
# Out:
#                                                    title  \
# 0      donald trump sends embarrassing new year eve m...
# 1      drunk bragging trump staffer started russian c...
# 2      sheriff david clarke becomes internet joke thr...
# 3      trump obsessed even obama name coded website i...
# 4      pope francis called donald trump christmas speech
# ...                                                  ...
# 44892  north korea shipments syria chemical arms agen...
# 44894    lexisnexis withdrew two products chinese market
# 44895             minsk cultural hub becomes authorities
# 44896  vatican upbeat possibility pope francis visiti...
# 44897           indonesia buy billion worth russian jets
#
#                                                     text    subject  \
# 0      donald trump wish americans happy new year lea...       News
# 1      house intelligence committee chairman devin nu...       News
# 2      friday revealed former milwaukee sheriff david...       News
# 3      christmas day donald trump announced would bac...       News
# 4      pope francis used annual christmas day message...       News
# ...                                                  ...        ...
# 44892  united nations two north korean shipments syri...  worldnews
# 44894  london lexisnexis provider legal regulatory bu...  worldnews
# 44895  minsk shadow disused soviet era factories mins...  worldnews
# 44896  moscow vatican secretary state cardinal pietro...  worldnews
# 44897  jakarta indonesia buy sukhoi fighter jets wort...  worldnews
#
#                     date  category
# 0      December 31, 2017         0
# 1      December 31, 2017         0
# 2      December 30, 2017         0
# 3      December 29, 2017         0
# 4      December 25, 2017         0
# ...                  ...       ...
# 44892   August 21, 2017          1
# 44894   August 22, 2017          1
# 44895   August 22, 2017          1
# 44896   August 22, 2017          1
# 44897   August 22, 2017          1
#
# [38270 rows x 5 columns]

# %% [markdown]
# #### Now I goint to work on the date column

# %%
# there some rows that have another information but not date-info I will delete them
df = df[df['date'].str.len() < 19]

# %%
def date_time(dtime):
    print("object type: ",dtime.dtype)
    dtime =pd.to_datetime(dtime) # convert it to datetime
    print("object type: ",dtime.dtype) # check datatype again
    print("min time: ",dtime.min()) # check when data begin
    print("max time: ",dtime.max()) # check when data end
    dtime = dtime.apply(lambda x: x.toordinal()) # we will change the effective to date column to ordinal
    return dtime
df['date'] = date_time(df['date'])
# Out:
# object type:  object
# object type:  datetime64[ns]
# min time:  2015-03-31 00:00:00
# max time:  2018-02-19 00:00:00

# %%
def split_words(news):
    news = news.split()
    return news

# %%
df['text'] = df['text'].apply(split_words)
df['title'] = df['title'].apply(split_words)
df
# Out:
#                                                    title  \
# 0      [donald, trump, sends, embarrassing, new, year...
# 1      [drunk, bragging, trump, staffer, started, rus...
# 2      [sheriff, david, clarke, becomes, internet, jo...
# 3      [trump, obsessed, even, obama, name, coded, we...
# 4      [pope, francis, called, donald, trump, christm...
# ...                                                  ...
# 44892  [north, korea, shipments, syria, chemical, arm...
# 44894  [lexisnexis, withdrew, two, products, chinese,...
# 44895       [minsk, cultural, hub, becomes, authorities]
# 44896  [vatican, upbeat, possibility, pope, francis, ...
# 44897    [indonesia, buy, billion, worth, russian, jets]
#
#                                                     text    subject    date  \
# 0      [donald, trump, wish, americans, happy, new, y...       News  736694
# 1      [house, intelligence, committee, chairman, dev...       News  736694
# 2      [friday, revealed, former, milwaukee, sheriff,...       News  736693
# 3      [christmas, day, donald, trump, announced, wou...       News  736692
# 4      [pope, francis, used, annual, christmas, day, ...       News  736688
# ...                                                  ...        ...     ...
# 44892  [united, nations, two, north, korean, shipment...  worldnews  736562
# 44894  [london, lexisnexis, provider, legal, regulato...  worldnews  736563
# 44895  [minsk, shadow, disused, soviet, era, factorie...  worldnews  736563
# 44896  [moscow, vatican, secretary, state, cardinal, ...  worldnews  736563
# 44897  [jakarta, indonesia, buy, sukhoi, fighter, jet...  worldnews  736563
#
#        category
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 44892         1
# 44894         1
# 44895         1
# 44896         1
# 44897         1
#
# [35841 rows x 5 columns]

# %%
# to detect the most repeated keywords in df_sample'text'.
words = [wrd for x in df['text'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_text = Counter(words)
keywords_text = pd.DataFrame.from_dict(keywords_text, orient='index').reset_index()
keywords_text = keywords_text.sort_values(by=[0], ascending=False)
keywords_text.columns = ['word','count']
keywords_text.head(60)
# Out:
#                 word   count
# 1              trump  117952
# 252             said  109571
# 70             would   45803
# 33         president   45630
# 84            people   34111
# 21               one   30470
# 932            state   27544
# 5                new   25096
# 72              also   25029
# 0             donald   24812
# 160            house   23575
# 1023      republican   22751
# 489            obama   22067
# 203          clinton   22044
# 1796      government   21843
# 258           states   21755
# 6               year   20094
# 795            could   19544
# 826            white   18982
# 1364            told   18800
# 625           united   18776
# 48              like   18444
# 190         campaign   18360
# 228         election   17457
# 226              two   17378
# 371             time   17114
# 131             last   17084
# 1423           party   16762
# 15              news   15479
# 515       washington   15467
# 506            first   15274
# 31              even   14771
# 23           country   14484
# 17            former   14334
# 83              many   13234
# 92             years   13223
# 863      republicans   13026
# 1578             law   12773
# 95               say   12599
# 60          american   12497
# 202          hillary   12437
# 405             made   12428
# 238              may   12313
# 295         security   12311
# 345              get   12286
# 916            court   12279
# 355            right   12211
# 2787         percent   12103
# 1199        national   12069
# 71              make   12020
# 170               us   11922
# 900        political   11875
# 166            going   11850
# 576            since   11830
# 113          twitter   11686
# 122     presidential   11672
# 16             media   11573
# 835              via   11509
# 207   administration   11465
# 175           russia   11421

# %%
# to detect the most repeated keywords in df_sample'title'.
words = [wrd for x in df['title'] for wrd in x]
# importing Counter to count repeated words
from collections import Counter
keywords_title = Counter(words)
keywords_title = pd.DataFrame.from_dict(keywords_title, orient='index').reset_index()
keywords_title = keywords_title.sort_values(by=[0], ascending=False)
keywords_title.columns = ['word','count']
keywords_title.head(60)
# Out:
#              word  count
# 1           trump  12625
# 151         video   6039
# 104          says   2993
# 28          obama   2314
# 195         house   1779
# 74          watch   1556
# 892       hillary   1524
# 194         white   1423
# 4             new   1400
# 913       clinton   1365
# 364     president   1244
# 310        russia   1135
# 123          bill   1045
# 152    republican    982
# 169         state    896
# 149        senate    847
# 327         court    829
# 313      election    795
# 0          donald    786
# 1917        north    755
# 101          news    742
# 119           gop    741
# 438   republicans    729
# 1918        korea    711
# 188         calls    692
# 3635        china    680
# 122           tax    675
# 42          black    670
# 1009         vote    662
# 206      campaign    647
# 110         media    639
# 179        tweets    604
# 1629          may    595
# 233      breaking    594
# 371          anti    590
# 600           one    582
# 601          deal    569
# 763        police    568
# 154          gets    556
# 13        russian    530
# 1506         iran    529
# 387     democrats    507
# 7675           eu    501
# 164         party    498
# 372        muslim    497
# 2417   government    491
# 1724      america    491
# 1779        talks    480
# 899        attack    477
# 24         people    476
# 281       twitter    468
# 50            fbi    459
# 2214          law    459
# 361        leader    458
# 63         former    457
# 62           back    454
# 283          plan    452
# 191         first    452
# 153       senator    445
# 904         chief    443

# %%
df.head(5)
# Out:
#                                                title  \
# 0  [donald, trump, sends, embarrassing, new, year...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, internet, jo...
# 3  [trump, obsessed, even, obama, name, coded, we...
# 4  [pope, francis, called, donald, trump, christm...
#
#                                                 text subject    date  category
# 0  [donald, trump, wish, americans, happy, new, y...    News  736694         0
# 1  [house, intelligence, committee, chairman, dev...    News  736694         0
# 2  [friday, revealed, former, milwaukee, sheriff,...    News  736693         0
# 3  [christmas, day, donald, trump, announced, wou...    News  736692         0
# 4  [pope, francis, used, annual, christmas, day, ...    News  736688         0

# %%
def joining_list(news):
    news = " ".join(str(i) for i in news) # Convert to string
    return news

# %%
df['text'] = df['text'].apply(joining_list)
df['title'] = df['title'].apply(joining_list)
df
# Out:
#                                                    title  \
# 0      donald trump sends embarrassing new year eve m...
# 1      drunk bragging trump staffer started russian c...
# 2      sheriff david clarke becomes internet joke thr...
# 3      trump obsessed even obama name coded website i...
# 4      pope francis called donald trump christmas speech
# ...                                                  ...
# 44892  north korea shipments syria chemical arms agen...
# 44894    lexisnexis withdrew two products chinese market
# 44895             minsk cultural hub becomes authorities
# 44896  vatican upbeat possibility pope francis visiti...
# 44897           indonesia buy billion worth russian jets
#
#                                                     text    subject    date  \
# 0      donald trump wish americans happy new year lea...       News  736694
# 1      house intelligence committee chairman devin nu...       News  736694
# 2      friday revealed former milwaukee sheriff david...       News  736693
# 3      christmas day donald trump announced would bac...       News  736692
# 4      pope francis used annual christmas day message...       News  736688
# ...                                                  ...        ...     ...
# 44892  united nations two north korean shipments syri...  worldnews  736562
# 44894  london lexisnexis provider legal regulatory bu...  worldnews  736563
# 44895  minsk shadow disused soviet era factories mins...  worldnews  736563
# 44896  moscow vatican secretary state cardinal pietro...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jets wort...  worldnews  736563
#
#        category
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 44892         1
# 44894         1
# 44895         1
# 44896         1
# 44897         1
#
# [35841 rows x 5 columns]

# %%
df["length_text"] = [len(word.split()) for word in df["text"]]
df
# Out:
#                                                    title  \
# 0      donald trump sends embarrassing new year eve m...
# 1      drunk bragging trump staffer started russian c...
# 2      sheriff david clarke becomes internet joke thr...
# 3      trump obsessed even obama name coded website i...
# 4      pope francis called donald trump christmas speech
# ...                                                  ...
# 44892  north korea shipments syria chemical arms agen...
# 44894    lexisnexis withdrew two products chinese market
# 44895             minsk cultural hub becomes authorities
# 44896  vatican upbeat possibility pope francis visiti...
# 44897           indonesia buy billion worth russian jets
#
#                                                     text    subject    date  \
# 0      donald trump wish americans happy new year lea...       News  736694
# 1      house intelligence committee chairman devin nu...       News  736694
# 2      friday revealed former milwaukee sheriff david...       News  736693
# 3      christmas day donald trump announced would bac...       News  736692
# 4      pope francis used annual christmas day message...       News  736688
# ...                                                  ...        ...     ...
# 44892  united nations two north korean shipments syri...  worldnews  736562
# 44894  london lexisnexis provider legal regulatory bu...  worldnews  736563
# 44895  minsk shadow disused soviet era factories mins...  worldnews  736563
# 44896  moscow vatican secretary state cardinal pietro...  worldnews  736563
# 44897  jakarta indonesia buy sukhoi fighter jets wort...  worldnews  736563
#
#        category  length_text
# 0             0          263
# 1             0          183
# 2             0          338
# 3             0          270
# 4             0          212
# ...         ...          ...
# 44892         1          279
# 44894         1           74
# 44895         1          173
# 44896         1          116
# 44897         1          134
#
# [35841 rows x 6 columns]

# %%
print(df.iloc[6,1])
# Out:
# donald trump spent good portion day golf club marking th day done since taking oath office must bad game trump lashed fbi deputy director andrew mccabe twitter following report saying mccabe plans retire months report follows mccabe testimony front congressional committees week well mounting criticism republicans regarding russia probe naturally trump attacked mccabe lie fbi deputy director andrew mccabe man charge along leakin james comey phony hillary clinton investigation including illegally deleted emails given wife campaign clinton puppets investigation trump tweeted fbi deputy director andrew mccabe man charge along leakin james comey phony hillary clinton investigation including illegally deleted emails given wife campaign clinton puppets investigation donald trump realdonaldtrump december stop fbi deputy director andrew mccabe racing clock retire full benefits days go donald trump realdonaldtrump december wow fbi lawyer james baker reassigned according foxnews donald trump realdonaldtrump december intel trump disposal getting information fox news mccabe spent career fight terrorism attacked called president trump fact checked claim wife receiving campaign politifact noted late july trump tweet andrew mccabe significant distortion facts implication mccabe got clinton political favor make much sense look evidence july tweet rated mostly false trump repeats lies knows supporters believe without bothering google still lie though photo zach gibson pool getty images
