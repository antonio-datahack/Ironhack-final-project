# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
df = pd.read_csv('../data/df_fake_news.csv')

# %%
df = df[df['text'].notnull()]
df = df.dropna()
df.reset_index(inplace=True)
#df = df.drop(axis=1, columns='level_0')
df
# Out:
#        index                                              title  \
# 0          0  donald trump send embarrass new year eve messa...
# 1          1  drunk brag trump staffer start russian collus ...
# 2          2  sheriff david clark becom internet joke threat...
# 3          3      trump obsess even obama name code websit imag
# 4          4      pope franci call donald trump christma speech
# ...      ...                                                ...
# 38208  38259  north korea shipment syria chemic arm agenc in...
# 38209  38260       lexisnexi withdrew two product chines market
# 38210  38261                      minsk cultur hub becom author
# 38211  38262    vatican upbeat possibl pope franci visit russia
# 38212  38263     indonesia buy dollar billion worth russian jet
#
#                                                     text    subject    date  \
# 0      donald trump wish american happi new year leav...       News  736694
# 1      hous intellig committe chairman devin nune go ...       News  736694
# 2      friday reveal former milwauke sheriff david cl...       News  736693
# 3      christma day donald trump announc back work fo...       News  736692
# 4      pope franci use annual christma day messag reb...       News  736688
# ...                                                  ...        ...     ...
# 38208  unit nation two north korean shipment syrian g...  worldnews  736562
# 38209  london lexisnexi provid legal regulatori busi ...  worldnews  736563
# 38210  minsk shadow disus sovietera factori minsk str...  worldnews  736563
# 38211  moscow vatican secretari state cardin pietro p...  worldnews  736563
# 38212  jakarta indonesia buy sukhoi fighter jet worth...  worldnews  736563
#
#        category  length_text
# 0             0          255
# 1             0          178
# 2             0          315
# 3             0          238
# 4             0          208
# ...         ...          ...
# 38208         1          275
# 38209         1           73
# 38210         1          169
# 38211         1          116
# 38212         1          136
#
# [38213 rows x 7 columns]

# %%
df = df.drop(axis=1, columns='index')

# %%
def stopwords(news):
    news = news.lower().split()

    return news

# %%
df['text'] = df['text'].apply(stopwords)
df['title'] = df['title'].apply(stopwords)
df
# Out:
#                                                    title  \
# 0      [donald, trump, send, embarrass, new, year, ev...
# 1      [drunk, brag, trump, staffer, start, russian, ...
# 2      [sheriff, david, clark, becom, internet, joke,...
# 3      [trump, obsess, even, obama, name, code, websi...
# 4      [pope, franci, call, donald, trump, christma, ...
# ...                                                  ...
# 38208  [north, korea, shipment, syria, chemic, arm, a...
# 38209  [lexisnexi, withdrew, two, product, chines, ma...
# 38210                [minsk, cultur, hub, becom, author]
# 38211  [vatican, upbeat, possibl, pope, franci, visit...
# 38212  [indonesia, buy, dollar, billion, worth, russi...
#
#                                                     text    subject    date  \
# 0      [donald, trump, wish, american, happi, new, ye...       News  736694
# 1      [hous, intellig, committe, chairman, devin, nu...       News  736694
# 2      [friday, reveal, former, milwauke, sheriff, da...       News  736693
# 3      [christma, day, donald, trump, announc, back, ...       News  736692
# 4      [pope, franci, use, annual, christma, day, mes...       News  736688
# ...                                                  ...        ...     ...
# 38208  [unit, nation, two, north, korean, shipment, s...  worldnews  736562
# 38209  [london, lexisnexi, provid, legal, regulatori,...  worldnews  736563
# 38210  [minsk, shadow, disus, sovietera, factori, min...  worldnews  736563
# 38211  [moscow, vatican, secretari, state, cardin, pi...  worldnews  736563
# 38212  [jakarta, indonesia, buy, sukhoi, fighter, jet...  worldnews  736563
#
#        category  length_text
# 0             0          255
# 1             0          178
# 2             0          315
# 3             0          238
# 4             0          208
# ...         ...          ...
# 38208         1          275
# 38209         1           73
# 38210         1          169
# 38211         1          116
# 38212         1          136
#
# [38213 rows x 6 columns]

# %%
df.to_csv(f'../data/tableau_fake_news.csv', index=False)
